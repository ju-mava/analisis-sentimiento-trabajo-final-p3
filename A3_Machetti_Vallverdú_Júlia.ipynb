# %% [markdown]
# <a href="https://colab.research.google.com/github/ju-mava/analisis-sentimiento-trabajo-final-p3/blob/main/A3_Machetti_Vallverd%C3%BA_J%C3%BAlia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En este notebook, utilizaremos diferentes tipos de redes neuronales para realizar el análisis de sentimiento del dataset de Sentiment140.
#
# De este modo, para análisis de sentimiento, construïmos un modelo de aprendizaje profundo con varios tipos de RNNs y diversos parámetros. Nos quedamos con el mejor modelo, es decir, aquel que obtenga los mejores resultados en el conjunto de evaluación. Probar LIME con algunas instancias por cada categoría.

# %% [markdown]
# # Análisis, preprocesamiento y preparación de los datos

# %%
import pandas as pd

# %%
#Cargamos el dataset en CSV como un dataframe

sentiment140 = pd.read_csv('training.1600000.processed.noemoticon.csv', encoding='latin-1', header=None)

# %%
# Asignar nombres a las columnas
sentiment140.columns = ['polarity', 'id', 'date', 'query', 'user', 'text']

# %%
# Muestreo estratificado para obtener 200.000 instancias manteniendo la proporción de clases
#Sobreescribimos el dataframe previo
sentiment140 = sentiment140.groupby('polarity', group_keys=False).apply(
    lambda x: x.sample(frac=200000/len(sentiment140), random_state=42)
).reset_index(drop=True)
# Out:
# <ipython-input-14-b17eeecbcd17>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sentiment140 = sentiment140.groupby('polarity', group_keys=False).apply(

# %%
from sklearn.model_selection import train_test_split

# División en entrenamiento y temp (validación + test)
train_sentiment140, temp_sentiment140 = train_test_split(sentiment140, test_size=0.2, random_state=42, stratify=sentiment140['polarity'])

# División de temp en validación y test
val_sentiment140, test_sentiment140 = train_test_split(temp_sentiment140, test_size=0.5, random_state=42, stratify=temp_sentiment140['polarity'])

# %%
# Ahora tenemos tres conjuntos
print(f"Train: {len(train_sentiment140)} muestras")
print(f"Validación: {len(val_sentiment140)} muestras")
print(f"Test: {len(test_sentiment140)} muestras")
# Out:
# Train: 160000 muestras
# Validación: 20000 muestras
# Test: 20000 muestras

# %% [markdown]
# Vamos a concatenar todos los splits del dataset en un único dataframe, en el que creamos una columna especificando si el split es el dataset de entrenamiento, de validación o de evaluación.

# %%
df_list = []

for df_split, split_name in [(train_sentiment140, "train"), (val_sentiment140, "dev"), (test_sentiment140, "test")]:
    df_split = df_split.copy()
    df_split["split"] = split_name
    df_list.append(df_split)

df = pd.concat(df_list)
df.head()
# Out:
#         polarity          id                          date     query  \
# 81188          0  2183146110  Mon Jun 15 14:06:26 PDT 2009  NO_QUERY
# 94598          0  2245416131  Fri Jun 19 16:06:04 PDT 2009  NO_QUERY
# 105172         4  2065364209  Sun Jun 07 08:26:35 PDT 2009  NO_QUERY
# 96404          0  2255165705  Sat Jun 20 10:51:24 PDT 2009  NO_QUERY
# 173301         4  2044644480  Fri Jun 05 09:38:13 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 81188       lbartkowiak                @JBartkowiak  I really miss my son
# 94598          agoolsby  @stephenelliot Sorry so boring.  But good work...
# 105172        ezekiel78  @floydie14 don't forget to be in college tomor...
# 96404   FrugaliciousMom  @lizzydear me too! My poor blk Lincoln is tell...
# 173301   littleredwitch  @michellehv Hi Michelle! How are you? How is y...
#
#         split
# 81188   train
# 94598   train
# 105172  train
# 96404   train
# 173301  train

# %%
# Distribucion de instancias por clases (i.e. estrellas)

import matplotlib.pyplot as plt

df["polarity"].value_counts(ascending=True).plot.barh()
plt.title("Frequency of Classes")
plt.rcParams['figure.figsize'] = [10, 80]
plt.show()

# %%
# Nos quedamos con las columnas que nos interesan
df = df[['text', 'polarity', 'split']]
df
# Out:
#                                                      text  polarity  split
# 81188                 @JBartkowiak  I really miss my son          0  train
# 94598   @stephenelliot Sorry so boring.  But good work...         0  train
# 105172  @floydie14 don't forget to be in college tomor...         4  train
# 96404   @lizzydear me too! My poor blk Lincoln is tell...         0  train
# 173301  @michellehv Hi Michelle! How are you? How is y...         4  train
# ...                                                   ...       ...    ...
# 25683   #lions Things sure not going to script in Sout...         0   test
# 178822  Finally found the Bran Van 3000 song I've been...         4   test
# 97445   I'm kind of not happy at the moment.  But Ferr...         0   test
# 2589    What a fantastic Sunday treat...  http://short...         0   test
# 176618  #Giro - For a moment there, I thought Twitter ...         4   test
#
# [200000 rows x 3 columns]

# %% [markdown]
# Vamos a dividir nuevamente el dataframe en tres, uno por split, aleatorizar los conjuntos de datos.

# %%
import random
random.seed(0)

df_train = df[df['split'] == 'train']
df_valid = df[df['split'] == 'dev']
df_test = df[df['split'] == 'test']

df_train = df_train.sample(frac=1)
df_valid = df_valid.sample(frac=1)
df_test = df_test.sample(frac=1)

df_train
# Out:
#                                                      text  polarity  split
# 194685   @ddlovato thanks demi for the advice!  â¥â¥â¥         4  train
# 146327  Sharing my breakfast with a blackbird..... I t...         4  train
# 91971   P.S Was gona do Wossy bk club as well as other...         0  train
# 57235   Girly Nite 2nite with face masks and takeaway....         0  train
# 9744                               I miss school already          0  train
# ...                                                   ...       ...    ...
# 140105  @davecool83 I fell very honored ;) N thx 4 the...         4  train
# 7041    all this talk of up being The best movie of th...         0  train
# 19776   Probably the one and only time we will see Jor...         0  train
# 70728                Salad from krogers...  I was hungry.         0  train
# 1549    @MILEYCYRUS  WHAT ABOUT ME ??  I VOTE EVERY DA...         0  train
#
# [160000 rows x 3 columns]

# %%
X_train = df_train['text']
X_valid = df_valid['text']
X_test = df_test['text']

X_train
# Out:
# 194685     @ddlovato thanks demi for the advice!  â¥â¥â¥
# 146327    Sharing my breakfast with a blackbird..... I t...
# 91971     P.S Was gona do Wossy bk club as well as other...
# 57235     Girly Nite 2nite with face masks and takeaway....
# 9744                                 I miss school already
#                                 ...
# 140105    @davecool83 I fell very honored ;) N thx 4 the...
# 7041      all this talk of up being The best movie of th...
# 19776     Probably the one and only time we will see Jor...
# 70728                  Salad from krogers...  I was hungry.
# 1549      @MILEYCYRUS  WHAT ABOUT ME ??  I VOTE EVERY DA...
# Name: text, Length: 160000, dtype: object

# %%
#0 refers to the negative and 1 to the positive
y_train = df_train['polarity'].map({0:0, 4:1}).values
y_valid = df_valid['polarity'].map({0:0, 4:1}).values
y_test = df_test['polarity'].map({0:0, 4:1}).values
y_train
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# # Entrenamiento de redes neuronales

# %% [markdown]
# En estas líneas de código se está realizando el preprocesamiento de texto para poder utilizar los datos de texto en un modelo de redes neuronales.
#
# Primero, se importa la clase Tokenizer de Keras. Esta clase proporciona una forma simple de preprocesar datos de texto para su uso en modelos de redes neuronales.
#
# Luego, se crea una instancia de Tokenizer y se ajusta a los datos de entrenamiento con el método fit_on_texts. Esto construye un vocabulario de todas las palabras únicas en los datos de entrenamiento y asigna a cada palabra un índice entero único.
#
# A continuación, se utiliza el método texts_to_sequences para convertir los datos de entrenamiento, validación y prueba en secuencias de índices de palabras. Cada palabra en el texto se reemplaza por el índice correspondiente del vocabulario construido anteriormente.
#
# Una vez que se han convertido los datos de texto en secuencias de índices, se pueden utilizar como entrada para un modelo de redes neuronales. Sin embargo, tendremos que utilizar la función pad_sequences de Keras para asegurarnos de que todas las secuencias tengan la misma longitud antes de proporcionarlas como entrada al modelo.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding, Bidirectional
from tensorflow.keras.models import Sequential
from numpy import array
from tensorflow.keras.preprocessing.text import one_hot

from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout

# %% [markdown]
# **Tokenización y preprocesamiento**
#
# Propósito: Convertir texto en representación numérica que la red neuronal pueda procesar.
# Proceso:
#
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(X_train)
#
#     Tokenizer():
#         Crea un diccionario que asigna cada palabra única a un índice numérico.
#         Ejemplo: {"el": 1, "servicio": 2, "excelente": 3, ...}.
#     fit_on_texts(X_train):
#         Analiza todos los textos de entrenamiento para construir el vocabulario.
#         Solo se hace con los datos de entrenamiento para evitar "fugas" de información.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_valid_seq = tokenizer.texts_to_sequences(X_valid)
X_test_seq = tokenizer.texts_to_sequences(X_test)
X_train_seq
# Out:
# [[15626, 116, 70, 218, 12, 3944, 1106, 49, 18, 551, 62, 37],
#  [8297, 5, 977, 1898, 23, 389, 126, 13, 896, 4843],
#  [39706,
#   1,
#   46,
#   475,
#   1111,
#   1,
#   62,
#   16,
#   4715,
#   134,
#   15,
#   27,
#   592,
#   8,
#   4,
#   36,
#   37,
#   307,
#   1,
#   68,
#   190,
#   2219,
#   523],
#  [1, 81, 5, 4222, 1010, 14],
#  [6453, 82, 10, 1862, 196, 59, 464, 122, 22, 83, 16, 4, 129, 30, 919],
#  [18821, 58, 5516, 955, 513, 49],
#  [69, 115, 218, 1, 64, 24, 197, 76],
#  [15627,
#   49,
#   607,
#   9387,
#   8,
#   234,
#   45,
#   46,
#   130,
#   33,
#   69,
#   142,
#   2,
#   67,
#   457,
#   8,
#   13,
#   3,
#   78,
#   849,
#   3306],
#  [47, 10, 373],
#  [47, 32, 21, 5, 654, 6, 39707, 171, 230, 937, 390, 5, 852, 15, 91],
#  [512,
#   11,
#   3,
#   279,
#   141,
#   6752,
#   237,
#   32,
#   3407,
#   1171,
#   107,
#   8804,
#   10,
#   39708,
#   5733,
#   539,
#   162,
#   146,
#   145,
#   22,
#   801],
#  [39709, 11, 33, 30],
#  [458, 1530, 1, 16, 4, 129, 30],
#  [39710,
#   137,
#   12,
#   539,
#   13516,
#   991,
#   58,
#   1676,
#   1747,
#   17,
#   436,
#   1326,
#   511,
#   2,
#   22,
#   119,
#   1930,
#   93,
#   18,
#   9,
#   25,
#   133,
#   92,
#   256],
#  [24698,
#   24699,
#   8,
#   113,
#   28,
#   2315,
#   10,
#   3,
#   4456,
#   4844,
#   306,
#   3,
#   4456,
#   4844,
#   69,
#   1720,
#   21,
#   6454],
#  [69, 142, 2, 67, 489, 103, 1, 147, 31, 2, 67, 158, 17, 174, 126],
#  [39711, 753, 198, 82],
#  [39712,
#   302,
#   1414,
#   41,
#   24,
#   493,
#   117,
#   1,
#   25,
#   1976,
#   374,
#   131,
#   662,
#   789,
#   65,
#   3554,
#   51,
#   1721,
#   4457],
#  [407, 50],
#  [6455, 185, 35, 75, 247, 23, 1965],
#  [47, 2, 4, 238],
#  [564, 242, 260, 7, 46, 27, 487, 20, 31, 52, 623, 21, 158, 172],
#  [1011, 36, 19, 1816, 10, 7876, 7449, 39713, 7876],
#  [1, 94, 4, 1898, 843],
#  [39714, 1, 59, 191, 8, 4, 3351, 1159, 6, 291, 77, 196, 2, 22, 623],
#  [39715,
#   1,
#   59,
#   185,
#   57,
#   1,
#   212,
#   2,
#   10,
#   24700,
#   2140,
#   26,
#   470,
#   158,
#   6,
#   1172,
#   39716,
#   16,
#   347],
#  [39717,
#   16,
#   7,
#   292,
#   9,
#   36,
#   6,
#   58,
#   24,
#   86,
#   111,
#   86,
#   7,
#   4583,
#   2246,
#   2390,
#   7050,
#   10959,
#   5517,
#   3408,
#   10,
#   130],
#  [18822, 131, 13, 6, 756, 10, 14, 144, 3, 18822, 1, 59],
#  [1455,
#   101,
#   1863,
#   181,
#   4,
#   98,
#   30,
#   89,
#   124,
#   63,
#   1563,
#   416,
#   1722,
#   7,
#   4,
#   24701,
#   72,
#   7,
#   131,
#   67,
#   14,
#   24702],
#  [1442,
#   9388,
#   98,
#   39718,
#   86,
#   192,
#   1442,
#   1,
#   565,
#   963,
#   3,
#   964,
#   6,
#   24,
#   15,
#   91,
#   3,
#   238,
#   433],
#  [39719, 18, 3036, 7450, 16, 2870, 45],
#  [15,
#   42,
#   359,
#   413,
#   15628,
#   65,
#   1,
#   81,
#   1,
#   139,
#   343,
#   459,
#   437,
#   65,
#   31,
#   13,
#   29,
#   26,
#   40,
#   8,
#   18823,
#   74,
#   325,
#   328],
#  [11,
#   94,
#   12,
#   4,
#   10960,
#   600,
#   2,
#   1082,
#   120,
#   655,
#   6,
#   300,
#   1038,
#   6,
#   22,
#   3555,
#   165,
#   21],
#  [485,
#   1319,
#   427,
#   36,
#   1196,
#   55,
#   110,
#   290,
#   9,
#   20,
#   846,
#   108,
#   118,
#   47,
#   2,
#   140,
#   244,
#   191,
#   275],
#  [39720, 122, 499, 4, 24703, 487, 4, 563, 51, 14],
#  [8805, 2546, 1531, 57, 16, 2, 226, 23, 1450, 277],
#  [573,
#   13517,
#   1214,
#   9389,
#   1366,
#   1,
#   46,
#   191,
#   45,
#   20,
#   16,
#   4,
#   315,
#   12,
#   39721,
#   11,
#   14,
#   6,
#   1,
#   62,
#   59,
#   116],
#  [1010, 27, 333, 6, 62, 34, 188, 183, 39, 442, 56, 231, 39722],
#  [15629, 73],
#  [1, 60, 94, 4, 78, 322],
#  [39723,
#   88,
#   48,
#   581,
#   32,
#   39724,
#   123,
#   13518,
#   2992,
#   15,
#   13518,
#   8,
#   26,
#   512,
#   13,
#   379,
#   10097,
#   2783,
#   24704,
#   18824,
#   24704],
#  [4018, 1472],
#  [39725,
#   1,
#   1181,
#   3,
#   39726,
#   252,
#   6,
#   118,
#   3,
#   12051,
#   1451,
#   1,
#   64,
#   28,
#   11,
#   7877,
#   381],
#  [2006, 13, 15630, 2597, 11, 186, 394, 50, 15, 200],
#  [39727,
#   2141,
#   701,
#   1,
#   20,
#   5310,
#   158,
#   4,
#   15631,
#   3409,
#   6,
#   38,
#   36,
#   36,
#   36,
#   36,
#   38],
#  [39728, 949, 1, 12052, 32, 71, 5734, 10, 2219, 126, 49],
#  [1215, 6199, 8, 20, 133, 95, 394],
#  [100, 4, 18825, 938],
#  [39729, 39, 149, 56, 39730, 18, 42, 348, 1, 25, 83, 85, 7, 472, 9],
#  [39731,
#   1,
#   108,
#   10,
#   7,
#   17,
#   645,
#   2,
#   14,
#   2267,
#   3,
#   92,
#   239,
#   473,
#   33,
#   156,
#   584,
#   119,
#   683,
#   623,
#   11,
#   473,
#   111],
#  [4716, 1367, 2, 10098],
#  [1768, 3556, 1071, 3037, 9],
#  [39732, 117, 1, 25, 83, 6, 24, 1899, 126],
#  [100, 15632, 17, 143, 1381, 3138],
#  [39733, 457, 428, 21, 109, 143, 47, 2, 22, 348],
#  [39734,
#   39735,
#   334,
#   1,
#   565,
#   158,
#   135,
#   90,
#   158,
#   1456,
#   341,
#   487,
#   2419,
#   1817,
#   4019,
#   2993],
#  [178, 219, 566, 11, 4, 271, 237, 2, 1864, 6753, 2, 300, 895, 104],
#  [5, 1001, 35, 333],
#  [184, 92, 73, 25, 98, 173, 39736, 15, 111, 42, 133],
#  [5, 632, 1, 94, 233],
#  [3352, 160, 969, 39737, 11, 1966],
#  [211, 68, 1, 208, 3, 78, 2268, 269, 1116, 24, 492, 5969, 13, 590],
#  [24705, 82, 150, 4, 730],
#  [39738, 5, 2017, 69, 3410, 414, 3188],
#  [39739, 98, 544, 53, 45, 3490],
#  [1457,
#   5,
#   738,
#   4717,
#   7051,
#   69,
#   208,
#   830,
#   10,
#   4717,
#   8298,
#   10961,
#   69,
#   10099,
#   2420,
#   15633,
#   425,
#   9],
#  [3189, 375, 338, 34, 3, 173, 490, 232, 118, 26, 7878, 8, 4341, 15, 361, 229],
#  [24706, 116, 291, 1967, 260, 24, 43, 1368],
#  [1, 90, 187, 209],
#  [39740, 15634, 1, 535, 2, 605, 39741, 6, 48, 95, 1931],
#  [84,
#   5,
#   1635,
#   1,
#   16,
#   36,
#   3190,
#   11,
#   996,
#   118,
#   26,
#   10,
#   4718,
#   3,
#   344,
#   73,
#   3856,
#   8,
#   2187,
#   2292,
#   213,
#   1256],
#  [839,
#   1,
#   170,
#   16,
#   2,
#   180,
#   10,
#   3,
#   3353,
#   11,
#   5,
#   640,
#   491,
#   1,
#   68,
#   297,
#   130,
#   51,
#   5,
#   228,
#   6,
#   70,
#   170,
#   28,
#   316,
#   89,
#   74,
#   486,
#   730,
#   1269],
#  [302,
#   3557,
#   27,
#   8,
#   5518,
#   51,
#   10962,
#   15635,
#   4984,
#   20,
#   370,
#   2,
#   180,
#   1,
#   64,
#   1845,
#   2,
#   41,
#   316],
#  [18826,
#   395,
#   42,
#   112,
#   18,
#   9,
#   509,
#   17,
#   41,
#   6456,
#   16,
#   95,
#   6200,
#   2,
#   12053,
#   2,
#   267,
#   723,
#   12,
#   3,
#   2745],
#  [24707, 1, 46, 3, 39742, 2099, 18, 150, 118, 42, 4, 39743, 45],
#  [1, 69, 376, 17, 2421, 1, 57, 22, 3411, 75, 69, 376, 15, 111, 10, 27],
#  [39744,
#   61,
#   16,
#   2,
#   377,
#   171,
#   160,
#   5,
#   7052,
#   5,
#   950,
#   1532,
#   186,
#   103,
#   15,
#   1,
#   94,
#   2,
#   31,
#   80,
#   126,
#   19,
#   1042,
#   2,
#   496,
#   39745],
#  [39746,
#   1,
#   147,
#   37,
#   2,
#   3,
#   2338,
#   422,
#   148,
#   6457,
#   32,
#   218,
#   88,
#   248,
#   9,
#   121,
#   254,
#   42,
#   102,
#   554,
#   33,
#   30,
#   422,
#   148],
#  [236, 60, 139, 22, 175, 2292],
#  [39747, 49, 1206, 53, 75, 461, 780],
#  [39748, 166, 36, 76, 310, 37, 2, 115, 124, 72, 19, 4845, 53],
#  [1052, 53, 39749, 39750, 39751],
#  [374, 46, 2, 18, 19, 2293, 941, 4, 467],
#  [39752, 343, 215, 23, 3, 7451, 6, 3945, 13, 1391, 4, 852],
#  [39, 149, 56, 39753, 166, 3, 5311, 35, 1399, 24708, 1399, 5311, 623],
#  [3038, 29, 23, 43, 6, 5, 1392, 281, 240, 14, 37, 80],
#  [1919, 10, 3, 754, 13, 449, 3558, 241, 158, 39754, 875, 72, 53, 46, 702],
#  [4985, 249, 172, 2220, 8299, 6, 39755, 1797, 2, 14],
#  [137,
#   15636,
#   47,
#   2,
#   521,
#   3,
#   577,
#   85,
#   7,
#   287,
#   41,
#   488,
#   19,
#   587,
#   12,
#   41,
#   8806,
#   201],
#  [39756, 1494, 99, 57, 367, 41, 1769, 1, 1932, 17, 5519],
#  [3946, 1, 182, 22, 83, 481, 114],
#  [24709, 1, 253, 123, 74, 2077, 1367, 897, 3, 267, 487, 25, 1976],
#  [39757,
#   236,
#   216,
#   7,
#   139,
#   3410,
#   9,
#   314,
#   85,
#   150,
#   388,
#   15,
#   7,
#   68,
#   10963,
#   9,
#   11,
#   2825,
#   2871,
#   10,
#   24710,
#   10100],
#  [39758, 28, 97, 524],
#  [1117, 4986, 1117, 302, 1, 66, 4, 1603, 4118, 258, 5, 723, 6, 26, 70, 4846],
#  [39759,
#   137,
#   9,
#   25,
#   28,
#   1,
#   1480,
#   23,
#   5,
#   2784,
#   228,
#   92,
#   73,
#   15,
#   408,
#   31,
#   360,
#   115,
#   39760,
#   507,
#   326],
#  [82, 2, 704, 1, 64, 36, 820, 38, 1072, 38, 1, 64, 39761, 203, 1741, 1225],
#  [15637,
#   3,
#   5312,
#   8,
#   88,
#   768,
#   11,
#   46,
#   249,
#   6458,
#   2,
#   868,
#   109,
#   6,
#   110,
#   8300,
#   109],
#  [19, 769, 27, 6201, 16, 2, 5313],
#  [39762,
#   129,
#   2720,
#   18827,
#   1360,
#   180,
#   38,
#   3354,
#   13519,
#   31,
#   11,
#   881,
#   244,
#   38,
#   121,
#   7,
#   1520,
#   747,
#   244,
#   1,
#   77,
#   54],
#  [70,
#   47,
#   2,
#   140,
#   6,
#   185,
#   1061,
#   55,
#   5,
#   802,
#   57,
#   613,
#   14,
#   1,
#   59,
#   249,
#   1,
#   64,
#   630,
#   10],
#  [89, 2, 677, 141, 3, 1781, 11, 9390, 126, 273, 39763],
#  [451, 566, 566, 12054, 138, 22, 47, 39, 442, 56, 231, 39764],
#  [749, 39765, 2221, 2872, 4719, 1798],
#  [1,
#   20,
#   697,
#   54,
#   444,
#   900,
#   5151,
#   5520,
#   2994,
#   2294,
#   611,
#   6,
#   26,
#   367,
#   4458,
#   1748,
#   107,
#   75,
#   580,
#   311,
#   4,
#   24711,
#   865,
#   231],
#  [39766,
#   51,
#   39767,
#   1481,
#   39768,
#   2995,
#   42,
#   4,
#   132,
#   45,
#   1143,
#   10,
#   14,
#   5,
#   39769,
#   35,
#   15638,
#   6,
#   207,
#   6754,
#   85,
#   1,
#   1245,
#   45,
#   762],
#  [4584, 13, 3, 1415, 12, 5, 3559, 1614, 1782, 14, 12, 5, 5314, 1833, 159],
#  [15639,
#   1,
#   121,
#   1002,
#   22,
#   11,
#   9391,
#   1,
#   24712,
#   5,
#   2598,
#   411,
#   10,
#   368,
#   32,
#   12,
#   2746,
#   36,
#   94,
#   2,
#   1495,
#   869,
#   4,
#   677,
#   2,
#   44,
#   9],
#  [18828,
#   137,
#   85,
#   1,
#   641,
#   19,
#   47,
#   2,
#   282,
#   2100,
#   9,
#   11,
#   4,
#   12055,
#   62,
#   59,
#   72,
#   17,
#   57,
#   261,
#   9,
#   13520,
#   105,
#   24,
#   1,
#   1270,
#   9],
#  [13, 5, 136, 2, 4342, 7879],
#  [20, 2674, 52, 13, 4585, 8301, 265, 2747, 22, 52, 69, 142, 2, 1458],
#  [39770, 39, 149, 56, 39771, 1191, 6, 15, 475],
#  [970, 469, 9, 15, 1723, 264, 2479, 9, 117, 1, 66, 4, 1271, 689, 11, 5, 965],
#  [39772, 660, 106],
#  [3, 39773, 8, 26, 133, 26, 93, 656, 3, 1107, 216],
#  [39774, 19, 1399, 46, 407, 6, 676, 19, 301, 2826, 39775, 1818, 72, 7, 77, 9],
#  [13, 5, 136, 2, 43],
#  [15640,
#   1,
#   69,
#   142,
#   360,
#   162,
#   256,
#   33,
#   331,
#   18829,
#   531,
#   23,
#   104,
#   6,
#   29,
#   341,
#   74,
#   1393,
#   243,
#   8,
#   252,
#   32,
#   36,
#   112,
#   188,
#   3,
#   288,
#   1021],
#  [39776,
#   106,
#   42,
#   3,
#   1552,
#   54,
#   555,
#   39777,
#   39778,
#   42,
#   24,
#   1029,
#   134,
#   154,
#   20,
#   2996,
#   5,
#   490],
#  [1553,
#   704,
#   5735,
#   1544,
#   397,
#   13,
#   1506,
#   1350,
#   468,
#   9,
#   4,
#   1770,
#   372,
#   18,
#   170,
#   13,
#   436],
#  [24713, 18, 5, 1112, 51, 4987, 447, 29],
#  [100, 4, 854, 228, 36, 710, 36, 1192],
#  [551, 255, 26],
#  [50, 2, 31, 29, 10, 43, 4343],
#  [514, 3, 4344, 36, 10964, 20, 4, 1615, 12, 1571, 7053],
#  [39779,
#   82,
#   10,
#   3,
#   1580,
#   2748,
#   1993,
#   122,
#   22,
#   784,
#   32,
#   12,
#   1427,
#   11,
#   3,
#   119,
#   941,
#   1214],
#  [24714, 295, 201, 11, 3, 196, 6, 763, 15641, 63, 9, 276, 14, 15, 111],
#  [971, 1507, 80, 51, 3, 1320, 6, 36, 12056],
#  [52, 11, 39780, 90, 6202, 6, 15642, 209],
#  [3039,
#   959,
#   4020,
#   35,
#   47,
#   10,
#   10965,
#   1361,
#   988,
#   1,
#   257,
#   306,
#   1257,
#   12,
#   196,
#   337,
#   4,
#   384,
#   63,
#   1222,
#   974],
#  [20, 220, 2, 4345, 6, 354, 21, 39781, 1, 247],
#  [39782, 82, 9, 8, 1819, 32, 98],
#  [39783, 1, 121, 170, 106, 1, 6459, 287, 14, 55, 7, 81],
#  [24715, 60, 39784, 10, 385, 648, 6, 1, 59, 1, 117, 18, 14, 36, 68, 591],
#  [39785, 147, 31, 9, 47, 2, 140, 26, 515, 283],
#  [75, 175, 13, 632],
#  [39786,
#   896,
#   23,
#   41,
#   423,
#   2391,
#   13,
#   816,
#   338,
#   7054,
#   1,
#   528,
#   9,
#   11,
#   5,
#   4346,
#   499,
#   3,
#   39787,
#   122,
#   613,
#   39788],
#  [2, 91, 13, 5, 508, 20, 472, 4, 635, 5736, 15, 1, 68, 301, 115, 126],
#  [66,
#   4,
#   1564,
#   11,
#   2512,
#   21,
#   2339,
#   1636,
#   6,
#   1677,
#   52,
#   11,
#   2188,
#   10,
#   54,
#   87,
#   73,
#   12,
#   1554,
#   103,
#   42,
#   52,
#   2,
#   1933],
#  [348,
#   26,
#   19,
#   255,
#   42,
#   156,
#   39789,
#   1459,
#   84,
#   137,
#   1,
#   310,
#   24716,
#   277,
#   335,
#   63,
#   128,
#   4720],
#  [304, 1, 108, 4988, 58, 11, 95, 3412, 24, 1047],
#  [8, 135, 176, 71, 5521, 170, 1555, 453],
#  [39790,
#   61,
#   94,
#   2,
#   208,
#   3,
#   118,
#   50,
#   12,
#   30,
#   85,
#   3,
#   39791,
#   23,
#   39792,
#   386,
#   1053,
#   32,
#   27,
#   8,
#   1496,
#   11,
#   4,
#   1460,
#   26],
#  [8, 23, 8807, 3238, 3, 2905],
#  [218,
#   1,
#   62,
#   582,
#   2,
#   91,
#   10,
#   3,
#   207,
#   185,
#   790,
#   13,
#   368,
#   9,
#   33,
#   30,
#   72,
#   356,
#   1048,
#   2,
#   5,
#   10101,
#   19,
#   47,
#   2,
#   16,
#   4,
#   39793],
#  [13,
#   5,
#   136,
#   2,
#   4847,
#   1678,
#   5970,
#   1079,
#   11,
#   24717,
#   131,
#   496,
#   14,
#   32,
#   19,
#   2422,
#   4721,
#   2,
#   4721,
#   212,
#   10,
#   3,
#   7452,
#   3238,
#   1834],
#  [39794,
#   61,
#   90,
#   7,
#   39795,
#   3857,
#   8,
#   95,
#   593,
#   10,
#   4989,
#   7,
#   6,
#   166,
#   1,
#   555,
#   3857,
#   17],
#  [39796,
#   166,
#   1361,
#   24718,
#   25,
#   98,
#   417,
#   65,
#   417,
#   35,
#   1461,
#   15,
#   327,
#   251,
#   117,
#   1,
#   145,
#   67,
#   39797,
#   3794,
#   126,
#   18,
#   1,
#   16,
#   2,
#   43],
#  [39798, 7, 35, 15, 118],
#  [10966, 7, 741, 1799, 2, 22, 2423, 36, 54, 1381, 7],
#  [39799, 71, 12, 196, 261, 206, 8808, 923, 6, 7453, 51, 691, 7, 59],
#  [117, 2, 33, 129, 30, 86, 91, 86, 1160, 425, 1572],
#  [39800,
#   14,
#   45,
#   2042,
#   510,
#   357,
#   54,
#   18,
#   60,
#   265,
#   88,
#   35,
#   3,
#   119,
#   178,
#   978,
#   25,
#   165,
#   6,
#   1,
#   25,
#   3191,
#   51,
#   96,
#   13],
#  [39,
#   132,
#   217,
#   39801,
#   154,
#   66,
#   17,
#   633,
#   4,
#   315,
#   227,
#   144,
#   116,
#   1,
#   351,
#   647,
#   39802],
#  [39803,
#   49,
#   36,
#   8302,
#   354,
#   17,
#   2513,
#   3040,
#   52,
#   11,
#   1,
#   125,
#   340,
#   9,
#   32,
#   18,
#   350,
#   2906,
#   225,
#   1,
#   57],
#  [39804, 17, 276, 14, 111, 544, 193, 483, 34, 17],
#  [39805,
#   72,
#   7,
#   3355,
#   174,
#   411,
#   150,
#   39806,
#   855,
#   34,
#   95,
#   243,
#   1724,
#   9392,
#   15643,
#   101,
#   42,
#   4848,
#   3409],
#  [8, 255, 1783],
#  [39807, 876, 264, 440, 1029, 82, 10, 3, 326, 73, 1236, 870, 577],
#  [39808,
#   42,
#   1333,
#   2,
#   1245,
#   273,
#   305,
#   1073,
#   6,
#   2785,
#   13521,
#   62,
#   43,
#   45,
#   76,
#   273,
#   206,
#   148],
#  [92, 4347, 303, 3356, 32, 16, 2, 4586, 126],
#  [66, 6460, 10, 676, 40, 465, 79, 165, 6460, 168],
#  [39809, 2827, 227, 162, 50],
#  [220,
#   2,
#   115,
#   21,
#   24719,
#   393,
#   65,
#   365,
#   29,
#   2,
#   39810,
#   393,
#   305,
#   305,
#   457,
#   60,
#   28,
#   99,
#   406,
#   406,
#   406],
#  [39811, 9, 145, 22, 801, 15, 53, 1182, 4, 657, 4722],
#  [4990, 304, 10, 205, 98, 30],
#  [1, 151, 85, 639, 35, 1176, 273, 14],
#  [72, 7, 77, 4, 1314, 12, 5, 5522, 3239, 240, 14, 59, 1900],
#  [92, 30, 11, 2222, 21, 3, 494],
#  [744, 7, 127, 14, 108, 15, 474, 1, 60, 108, 7, 288, 744],
#  [18830, 39812, 39813, 39814, 39815, 39816, 5971, 18831, 39817],
#  [4849, 77, 3, 279, 2, 131, 52],
#  [15, 10967, 179, 48, 2, 37, 176, 5152, 11],
#  [39818, 18832, 500, 191, 24, 1160, 1604, 160, 931, 85, 1, 278, 5737, 5315],
#  [39819,
#   76,
#   2018,
#   3,
#   24720,
#   6,
#   18833,
#   5523,
#   9,
#   25,
#   98,
#   5521,
#   1459,
#   8,
#   119,
#   3139],
#  [5, 828, 847, 568],
#  [81, 5, 483, 8, 3626],
#  [24721,
#   82,
#   10,
#   3,
#   552,
#   122,
#   282,
#   107,
#   2142,
#   11,
#   277,
#   85,
#   1,
#   31,
#   80,
#   72,
#   75,
#   36,
#   311,
#   329,
#   96,
#   122,
#   691,
#   249],
#  [18834, 613, 14, 3, 10102, 24722, 3, 12057, 6, 1301, 256, 1679],
#  [24723, 55, 645, 2, 3192, 39820, 99],
#  [39821, 341, 196, 295],
#  [24724,
#   76,
#   1,
#   472,
#   71,
#   50,
#   89,
#   215,
#   10,
#   4,
#   320,
#   10,
#   3,
#   235,
#   6,
#   215,
#   23,
#   3858,
#   523,
#   6,
#   4,
#   2424,
#   1192,
#   121,
#   22,
#   129],
#  [24725, 13522, 236, 1, 1197, 32, 1, 169, 1118, 4, 397, 10, 18835],
#  [12058,
#   479,
#   1,
#   151,
#   9393,
#   85,
#   1,
#   64,
#   2293,
#   941,
#   4,
#   12058,
#   9394,
#   54,
#   8,
#   23,
#   369,
#   4119,
#   1367,
#   229],
#  [39822, 70, 348],
#  [39823, 1, 25, 118, 1, 44, 31, 41, 437, 2, 5, 219],
#  [2340,
#   1,
#   1508,
#   71,
#   2,
#   3,
#   856,
#   1,
#   220,
#   2,
#   18,
#   26,
#   17,
#   33,
#   12,
#   5,
#   856,
#   35,
#   133,
#   1,
#   62,
#   59,
#   55,
#   10968,
#   21,
#   33,
#   3,
#   964,
#   1076],
#  [39824, 1863, 406],
#  [39825, 223, 406],
#  [1183,
#   228,
#   12,
#   12059,
#   26,
#   96,
#   19,
#   135,
#   190,
#   496,
#   3,
#   10103,
#   1,
#   46,
#   39826,
#   182,
#   43,
#   1054,
#   3708,
#   4223,
#   15,
#   114],
#  [334,
#   15,
#   683,
#   21,
#   3240,
#   5316,
#   6,
#   2117,
#   2873,
#   1533,
#   295,
#   1,
#   370,
#   130,
#   2,
#   1533],
#  [375,
#   6755,
#   25,
#   234,
#   39827,
#   39828,
#   2423,
#   4,
#   332,
#   67,
#   1,
#   57,
#   2341,
#   3,
#   1079,
#   24726,
#   34,
#   3,
#   9395],
#  [39829, 19, 120, 10, 7, 697, 20, 62, 127, 3, 259, 5153, 107],
#  [302, 39830, 82, 10, 5972, 14, 2, 99],
#  [989, 507, 24727, 2514, 26],
#  [18836,
#   156,
#   476,
#   32,
#   1086,
#   123,
#   571,
#   1209,
#   74,
#   476,
#   89,
#   843,
#   186,
#   29,
#   2316,
#   1315,
#   65,
#   1400,
#   496,
#   33,
#   30,
#   224,
#   2,
#   44,
#   262,
#   877,
#   18,
#   24],
#  [8303, 24728, 189, 163, 7, 119, 91],
#  [24729, 308, 1, 16, 2, 2675, 6, 2676, 244, 103],
#  [39831,
#   39832,
#   61,
#   390,
#   907,
#   6756,
#   88,
#   16,
#   129,
#   2043,
#   7,
#   1055,
#   39833,
#   24730,
#   273,
#   12060,
#   1030,
#   39834,
#   39835,
#   1153],
#  [3627, 5317, 1155, 28, 1742],
#  [43,
#   25,
#   112,
#   5,
#   1001,
#   51,
#   1130,
#   2786,
#   358,
#   43,
#   103,
#   7880,
#   503,
#   634,
#   156,
#   239,
#   4850,
#   308],
#  [20, 388, 459, 222, 1, 908, 1263, 41, 1769, 13523, 67, 7, 13, 3, 267, 723],
#  [39836,
#   794,
#   7,
#   230,
#   39837,
#   17,
#   1,
#   34,
#   2515,
#   49,
#   227,
#   206,
#   178,
#   693,
#   145,
#   22,
#   2,
#   202,
#   533],
#  [403, 8, 905, 14, 3, 280, 3, 50, 5, 1226, 821, 36, 1934, 436, 23, 3, 759],
#  [39838,
#   1,
#   25,
#   529,
#   12,
#   3,
#   178,
#   2907,
#   439,
#   12,
#   10969,
#   24,
#   361,
#   229,
#   1,
#   345,
#   16,
#   2,
#   90,
#   71,
#   12,
#   3,
#   777,
#   112,
#   39839],
#  [115, 656, 10, 196, 33, 495, 99, 1544],
#  [418, 54, 139, 31, 4, 1012, 791, 15, 1, 696, 10104, 54],
#  [28,
#   97,
#   99,
#   70,
#   45,
#   328,
#   4,
#   30,
#   2,
#   861,
#   869,
#   685,
#   15,
#   1,
#   257,
#   122,
#   861,
#   9,
#   409,
#   685],
#  [8, 15, 119, 255],
#  [1,
#   59,
#   70,
#   7454,
#   6,
#   1334,
#   1,
#   8304,
#   34,
#   156,
#   221,
#   504,
#   18,
#   236,
#   1,
#   248,
#   2749,
#   127,
#   1432,
#   10,
#   3,
#   600,
#   17,
#   584,
#   2,
#   908,
#   18,
#   147,
#   1835,
#   9],
#  [39840,
#   55,
#   269,
#   25,
#   9,
#   6,
#   284,
#   20,
#   547,
#   42,
#   348,
#   2,
#   22,
#   4,
#   177,
#   3413,
#   1901,
#   680],
#  [295, 303, 133, 57, 103, 613, 4, 138, 8809, 1073, 2059],
#  [39841, 1118],
#  [36, 54, 437, 414, 58, 33, 493, 1076],
#  [122, 282, 2575],
#  [2007, 29, 16, 39842, 13, 359, 6, 1, 59, 39843, 63, 4224],
#  [43, 103],
#  [55, 4, 2480, 13, 1643, 136, 74, 37, 1846, 189],
#  [89, 2, 39844, 2, 190, 3, 3795, 303, 932, 37, 974],
#  [39845,
#   166,
#   90,
#   8305,
#   1,
#   44,
#   17,
#   1242,
#   49,
#   95,
#   2547,
#   360,
#   3,
#   30,
#   17,
#   1,
#   908,
#   91,
#   46,
#   41,
#   136,
#   18837],
#  [4851, 72, 10105, 24731, 1800, 1031, 56, 39, 442, 56, 231, 39846],
#  [39847, 8306, 212, 366, 74, 283, 437],
#  [18838,
#   6461,
#   2295,
#   24732,
#   25,
#   879,
#   123,
#   24733,
#   65,
#   61,
#   351,
#   547,
#   21,
#   9,
#   65,
#   24734,
#   61,
#   57,
#   24,
#   760,
#   2,
#   1881,
#   1393,
#   497,
#   1394,
#   39848],
#  [573,
#   153,
#   7,
#   59,
#   5,
#   681,
#   581,
#   8307,
#   17,
#   16,
#   822,
#   17,
#   8810,
#   11,
#   3,
#   1184,
#   42,
#   165,
#   18,
#   1128,
#   8,
#   4,
#   444,
#   315,
#   138],
#  [24735, 186, 42, 21, 5, 363, 74, 42, 4, 2905, 106, 334, 17, 338, 129],
#  [610,
#   5,
#   534,
#   5518,
#   39849,
#   247,
#   193,
#   1351,
#   32,
#   39850,
#   75,
#   29,
#   74,
#   186,
#   1382,
#   1710,
#   3859,
#   110,
#   220,
#   355,
#   466,
#   927,
#   425,
#   188,
#   3860,
#   13],
#  [18839, 385, 8, 116, 7, 1383, 377, 41, 346, 2481, 314, 7055],
#  [118,
#   1,
#   64,
#   89,
#   2,
#   44,
#   71,
#   43,
#   122,
#   226,
#   85,
#   5,
#   15644,
#   1216,
#   656,
#   120,
#   39851],
#  [311, 4, 328, 30, 6, 19, 23, 43],
#  [39852, 724, 24, 53, 96],
#  [8308, 60, 718, 16, 248, 7, 168, 448, 120, 272],
#  [24736,
#   263,
#   34,
#   7,
#   57,
#   22,
#   11,
#   3,
#   649,
#   668,
#   21,
#   14,
#   5,
#   268,
#   18,
#   624,
#   281,
#   240,
#   14,
#   850,
#   40,
#   546],
#  [1, 59, 1, 59],
#  [5,
#   78,
#   99,
#   393,
#   172,
#   862,
#   39853,
#   39,
#   39854,
#   18840,
#   56,
#   3,
#   4348,
#   1534,
#   316,
#   3041,
#   3042,
#   522,
#   12,
#   112],
#  [1, 64, 111, 70, 114, 280, 11, 1366],
#  [1784,
#   5973,
#   138,
#   22,
#   1,
#   62,
#   182,
#   16,
#   2,
#   131,
#   208,
#   53,
#   6,
#   910,
#   3,
#   513,
#   18,
#   1,
#   121,
#   19,
#   33,
#   156,
#   3,
#   3140,
#   324,
#   89,
#   3,
#   1801,
#   2908],
#  [3861, 1, 20, 48, 1111, 33, 133, 14, 51, 54, 12, 5, 7455],
#  [13524, 42, 333, 65, 42, 20, 531, 2, 2019],
#  [2677, 9, 5, 3141, 3862, 13, 3, 18841, 266],
#  [39855,
#   242,
#   4120,
#   1,
#   248,
#   5,
#   2997,
#   3628,
#   104,
#   5524,
#   4021,
#   25,
#   55,
#   1802,
#   18842,
#   168,
#   421],
#  [24737,
#   36,
#   1270,
#   6,
#   3709,
#   8,
#   345,
#   2157,
#   18,
#   34,
#   3,
#   2787,
#   58,
#   128,
#   5,
#   39856,
#   960,
#   32,
#   6,
#   166,
#   4,
#   705,
#   39857,
#   857,
#   227],
#  [110, 252, 9, 7056, 507, 556],
#  [24738,
#   8,
#   5,
#   515,
#   15645,
#   5,
#   508,
#   227,
#   58,
#   24,
#   118,
#   418,
#   50,
#   1,
#   59,
#   58,
#   118,
#   63,
#   27,
#   46,
#   12,
#   410,
#   54,
#   12,
#   5,
#   6462],
#  [1, 94, 4, 320, 1223],
#  [58, 39858, 15, 200, 17, 37, 2599, 35, 482, 2, 14, 13, 752, 39859, 155, 104],
#  [39860,
#   406,
#   2,
#   4,
#   308,
#   12,
#   7881,
#   6,
#   1462,
#   15646,
#   23,
#   369,
#   26,
#   7,
#   68,
#   6757,
#   41,
#   12061,
#   23,
#   39861,
#   731],
#  [39862, 3629, 15, 111],
#  [39863, 24739, 2747, 10970, 39864, 39865, 39866, 39, 149, 56, 39867],
#  [20, 66, 5, 8811, 826, 642, 6, 3241, 2998, 11, 764, 1063],
#  [24740, 1321, 19, 98, 7, 6463, 39868, 24741, 24742, 7057, 15647, 13],
#  [5,
#   1376,
#   362,
#   15,
#   114,
#   51,
#   17,
#   6464,
#   2516,
#   4,
#   1460,
#   4,
#   5738,
#   211,
#   3,
#   12062,
#   25,
#   1865,
#   4,
#   78,
#   54,
#   92,
#   73],
#  [185, 77, 54, 12, 5, 4587, 39, 132, 217, 39869],
#  [355, 204, 141, 38, 39870, 38, 1, 46, 4349, 694],
#  [422, 1072, 781, 472, 3, 92, 5974, 5154, 1, 370, 17],
#  [18843, 15648, 72, 7, 81, 12, 4, 5739, 20, 287, 196, 6, 643, 226, 9],
#  [555,
#   3,
#   638,
#   1198,
#   6,
#   88,
#   313,
#   3,
#   638,
#   8,
#   990,
#   15,
#   1,
#   16,
#   840,
#   6,
#   332,
#   176,
#   4,
#   619,
#   11,
#   24743,
#   638,
#   2317],
#  [24744, 82, 88, 281, 240, 14, 755, 4, 1224],
#  [61, 37, 52, 2, 43, 2951, 160, 188, 89, 156, 133, 4, 146, 24, 215, 366, 2, 9],
#  [39871, 163, 7, 789, 52, 1, 81, 1, 345, 20, 94, 2, 37, 2, 140],
#  [39872, 2600, 39873, 2, 158, 45],
#  [16, 15649, 103, 39874],
#  [39875,
#   39876,
#   67,
#   1,
#   20,
#   2341,
#   1882,
#   1509,
#   105,
#   72,
#   1,
#   332,
#   1,
#   2341,
#   215,
#   23,
#   148,
#   8812,
#   8,
#   6203],
#  [10106, 18, 143, 263, 7456, 39877, 12063],
#  [1, 20, 10971, 239, 372, 6, 187, 8, 39878, 63, 17],
#  [39879, 457, 428],
#  [18844,
#   36,
#   1270,
#   410,
#   57,
#   45,
#   385,
#   8,
#   547,
#   42,
#   24,
#   63,
#   3,
#   2631,
#   10,
#   501,
#   12,
#   196],
#  [246,
#   154,
#   8813,
#   29,
#   13,
#   992,
#   12,
#   148,
#   519,
#   124,
#   1,
#   94,
#   4852,
#   607,
#   874,
#   9,
#   32],
#  [1, 77, 4, 914],
#  [39880, 143, 138, 22, 480, 2, 37, 3414, 264, 39881, 3043, 14, 4, 120, 931],
#  [69, 142, 2, 31, 32, 12, 27, 12064, 6, 278, 5, 831, 36, 2008, 36, 43, 13525],
#  [1010, 79, 91, 43, 143, 100, 13, 910, 14],
#  [47,
#   2,
#   67,
#   39882,
#   96,
#   3,
#   690,
#   35,
#   792,
#   14,
#   80,
#   6,
#   6758,
#   133,
#   10,
#   882,
#   6,
#   814,
#   32,
#   23,
#   5,
#   228],
#  [255, 1, 94, 249, 2, 335, 2],
#  [3560, 16, 7, 468, 5, 104, 4121, 3796, 49],
#  [364, 7457, 12065, 2, 13526, 41, 94, 10, 12066, 6, 5318],
#  [552, 5, 857, 757, 321, 757, 56, 39883],
#  [1, 60, 77, 4, 13527, 2874, 4, 780, 54, 11, 5975],
#  [39884,
#   27,
#   4588,
#   14,
#   45,
#   76,
#   12067,
#   125,
#   5740,
#   4,
#   28,
#   2576,
#   12,
#   830,
#   10,
#   3,
#   178,
#   18,
#   1,
#   117,
#   74,
#   25,
#   270,
#   1836,
#   12,
#   2721],
#  [39885, 49, 82, 1100, 155, 104, 37, 2, 115, 46, 7],
#  [39886,
#   1,
#   25,
#   11,
#   3,
#   1724,
#   6,
#   447,
#   123,
#   2,
#   67,
#   72,
#   7,
#   168,
#   83,
#   40,
#   18,
#   1,
#   516,
#   208,
#   7],
#  [39, 149, 56, 39887, 6, 1395],
#  [39888, 19, 119, 2577, 456, 15, 165],
#  [18845, 88, 35, 2269, 1, 169, 67, 130],
#  [39889, 27, 1782, 14, 2632, 75, 100, 18846],
#  [573, 19, 381, 2, 939, 1506],
#  [39890,
#   17,
#   275,
#   35,
#   7,
#   8814,
#   2,
#   208,
#   202,
#   9396,
#   105,
#   35,
#   7,
#   255,
#   32,
#   12,
#   41,
#   10972,
#   2722],
#  [4,
#   561,
#   100,
#   1168,
#   306,
#   1,
#   537,
#   5,
#   4991,
#   4844,
#   6,
#   57,
#   176,
#   74,
#   430,
#   2,
#   278,
#   7882,
#   15,
#   174],
#  [39891, 19, 124, 7, 147, 59, 19, 784, 2, 4589, 10, 152],
#  [198,
#   47,
#   2,
#   606,
#   1771,
#   11,
#   439,
#   22,
#   52,
#   10973,
#   3357,
#   242,
#   27,
#   8,
#   135,
#   22,
#   15650],
#  [39892,
#   607,
#   1,
#   20,
#   330,
#   32,
#   1,
#   68,
#   44,
#   17,
#   18,
#   1,
#   18847,
#   581,
#   3,
#   4723,
#   412,
#   18848,
#   339],
#  [84,
#   131,
#   7883,
#   21,
#   14,
#   8,
#   13,
#   20,
#   880,
#   2364,
#   7458,
#   3,
#   39893,
#   8,
#   15,
#   380,
#   110,
#   276,
#   3,
#   2118,
#   189],
#  [128, 1680, 4, 809, 96, 441, 109, 32, 10, 373],
#  [18849, 137, 42, 466, 7459, 93, 75, 45, 244, 28, 97, 2, 7],
#  [15651,
#   18850,
#   4459,
#   88,
#   240,
#   14,
#   337,
#   7,
#   27,
#   3307,
#   4992,
#   390,
#   39,
#   4993,
#   56,
#   39894],
#  [39895],
#  [220, 32, 10, 4, 698, 18, 13528, 570, 871, 34, 95, 243, 781, 144, 448, 10, 7],
#  [39896,
#   39897,
#   39898,
#   39899,
#   39900,
#   39901,
#   39902,
#   4724,
#   39903,
#   39904,
#   39905,
#   39906,
#   18851,
#   1131],
#  [39907,
#   61,
#   48,
#   32,
#   83,
#   6,
#   3,
#   2295,
#   25,
#   2601,
#   4122,
#   49,
#   291,
#   1196,
#   823,
#   48,
#   71,
#   3415,
#   546],
#  [265, 3, 909, 100, 4, 6204, 20, 4, 177, 132, 820, 360, 58, 11, 140],
#  [590, 6465, 78, 849, 1384, 1224, 42, 47, 2, 22, 39908, 39, 132, 217, 39909],
#  [47, 52, 2, 7884, 5, 387, 1083, 71, 18852, 24745, 178, 134],
#  [10974, 4590, 19, 24, 1294, 2, 190, 9, 360, 3, 597, 35, 133],
#  [39910, 1249, 176, 14, 2875, 172],
#  [39911, 374, 287, 7, 1, 75, 46, 7, 6205, 18, 374, 20, 31, 13, 41, 4994],
#  [39912, 39913, 2020, 7885, 1415, 13529, 1384, 39914, 39915, 1254, 10107],
#  [15, 255, 6, 773, 17, 19, 24, 128, 33, 3, 437, 1, 139],
#  [57,
#   760,
#   3,
#   741,
#   1644,
#   10,
#   126,
#   106,
#   24746,
#   1153,
#   39916,
#   6,
#   39917,
#   486,
#   305,
#   24747,
#   39,
#   442,
#   56,
#   231,
#   39918],
#  [24748,
#   24749,
#   594,
#   4,
#   315,
#   12,
#   8815,
#   9,
#   509,
#   187,
#   636,
#   9,
#   830,
#   196,
#   6,
#   287,
#   33,
#   41,
#   201,
#   63,
#   24748,
#   24749,
#   6,
#   24750,
#   56],
#  [295, 15652, 8, 32, 12, 39919, 550, 2, 3710],
#  [620, 89, 2, 140],
#  [5976, 1, 77, 54],
#  [39920, 338, 1443],
#  [15653, 36, 633, 192, 120, 2, 1023, 5, 940, 2482, 3711],
#  [13530,
#   498,
#   775,
#   61,
#   39921,
#   4853,
#   123,
#   482,
#   63,
#   99,
#   379,
#   12,
#   3,
#   50,
#   6,
#   1,
#   25,
#   52,
#   13,
#   222,
#   1,
#   2578,
#   229],
#  [39922, 8816, 5, 92, 666, 355, 204],
#  [39923, 106, 680, 39924, 792, 92, 657, 134],
#  [318, 584, 107],
#  [70, 135, 22, 4, 39925, 235],
#  [24751,
#   7,
#   168,
#   123,
#   361,
#   3,
#   173,
#   739,
#   23,
#   7460,
#   1,
#   117,
#   1,
#   66,
#   2009,
#   7,
#   168,
#   368,
#   18853,
#   1101,
#   1710,
#   26,
#   42,
#   1053,
#   32],
#  [153,
#   321,
#   39926,
#   56,
#   39927,
#   8,
#   175,
#   98,
#   26,
#   76,
#   23,
#   38,
#   1102,
#   38,
#   2143,
#   113,
#   153,
#   19,
#   20,
#   120,
#   19,
#   128,
#   5741,
#   1596,
#   137],
#  [117, 1, 145, 67, 2342, 11, 886, 18, 144, 928, 1605, 57, 131, 76, 1, 101, 15],
#  [218, 58, 181, 4, 2078, 854, 73],
#  [39928, 11, 331, 7058, 42, 4, 3947, 7886, 20, 498, 13, 5, 1666],
#  [578,
#   39929,
#   18854,
#   1,
#   330,
#   5,
#   463,
#   1,
#   330,
#   5,
#   463,
#   242,
#   39930,
#   472,
#   9,
#   1,
#   707,
#   9,
#   27,
#   1681,
#   50,
#   216],
#  [2993, 12, 3, 12068],
#  [80, 140, 36, 494, 20, 3, 513],
#  [39931,
#   14,
#   45,
#   102,
#   4,
#   577,
#   306,
#   8817,
#   105,
#   6206,
#   468,
#   109,
#   418,
#   648,
#   306,
#   96,
#   456,
#   5,
#   611],
#  [39932,
#   505,
#   1227,
#   10,
#   39933,
#   70,
#   39934,
#   12069,
#   3044,
#   6,
#   55,
#   533,
#   58,
#   15,
#   2007,
#   1,
#   16,
#   36,
#   2296],
#  [39935,
#   31,
#   608,
#   393,
#   4,
#   30,
#   549,
#   321,
#   2079,
#   56,
#   431,
#   7,
#   552,
#   187,
#   7,
#   35,
#   13,
#   3,
#   583,
#   105,
#   606,
#   1131],
#  [39936, 865, 8, 188, 15654],
#  [141,
#   3,
#   24752,
#   1032,
#   12,
#   2678,
#   214,
#   104,
#   107,
#   131,
#   13,
#   207,
#   4022,
#   95,
#   1565,
#   660,
#   74,
#   3193,
#   12,
#   7887,
#   24752],
#  [39937, 1, 1272, 1, 94, 747, 6, 1, 101, 5, 201, 35, 47],
#  [312,
#   10,
#   7461,
#   26,
#   1,
#   182,
#   37,
#   80,
#   6,
#   115,
#   39938,
#   89,
#   249,
#   6759,
#   2318,
#   8,
#   435,
#   60,
#   165],
#  [39939, 1206, 150, 547, 3556, 667, 44, 9, 107, 122, 496, 7, 11, 3, 1237],
#  [39940,
#   85,
#   351,
#   53,
#   270,
#   2,
#   795,
#   49,
#   65,
#   116,
#   41,
#   268,
#   39941,
#   24,
#   119,
#   2876,
#   2,
#   14,
#   24753,
#   170,
#   180,
#   302,
#   105,
#   356,
#   52],
#  [732,
#   126,
#   12,
#   539,
#   1,
#   121,
#   588,
#   29,
#   21,
#   4,
#   2297,
#   938,
#   9,
#   263,
#   34,
#   249,
#   7888,
#   14,
#   932,
#   37,
#   3045],
#  [50, 10, 162, 24754],
#  [3797, 241, 339],
#  [39942, 263, 34, 9],
#  [1,
#   94,
#   309,
#   3142,
#   10,
#   5,
#   162,
#   397,
#   72,
#   53,
#   16,
#   4,
#   826,
#   6,
#   68,
#   1281,
#   4,
#   1193,
#   210,
#   156,
#   14,
#   240,
#   14,
#   59,
#   15,
#   1,
#   68,
#   287,
#   53,
#   55,
#   163,
#   53,
#   5742],
#  [24755, 106, 82, 139, 22, 4, 112, 73, 32],
#  [1095, 18855, 2392, 26, 52, 11, 39943, 21, 36, 2392],
#  [24756, 12070, 4, 2158, 72, 42, 1322, 2247, 614, 107],
#  [27,
#   280,
#   8,
#   782,
#   6,
#   215,
#   23,
#   3,
#   364,
#   30,
#   3491,
#   42,
#   254,
#   164,
#   3,
#   881,
#   1,
#   94,
#   5,
#   774],
#  [10, 431, 33, 12, 5, 632, 8, 204, 1, 62, 16, 2, 446, 29, 360, 186, 64],
#  [39944, 2189, 51, 10108, 24757, 15655, 2223],
#  [24,
#   195,
#   116,
#   19,
#   558,
#   118,
#   26,
#   42,
#   45,
#   244,
#   84,
#   142,
#   5,
#   201,
#   11,
#   3,
#   267,
#   443,
#   35,
#   244,
#   39945,
#   116,
#   147,
#   392,
#   287,
#   14,
#   27],
#  [90, 33, 3, 112, 379, 10109, 1, 90, 158, 39, 442, 56, 231, 39946],
#  [39947,
#   9,
#   25,
#   8818,
#   11,
#   5,
#   2723,
#   299,
#   15,
#   1,
#   59,
#   304,
#   100,
#   39948,
#   9,
#   19,
#   20,
#   1043,
#   10,
#   3,
#   771,
#   406,
#   52],
#  [128, 224, 2, 278, 43, 9, 8, 2, 129, 4, 30, 2, 43, 11, 723],
#  [704,
#   62,
#   18856,
#   81,
#   63,
#   267,
#   294,
#   34,
#   79,
#   120,
#   615,
#   127,
#   148,
#   22,
#   61,
#   35,
#   3,
#   3561,
#   185,
#   139,
#   532,
#   19,
#   195,
#   122,
#   532],
#  [5, 1073, 35, 33, 4460, 6, 4461, 29, 51, 3, 3492, 27, 275],
#  [1819,
#   448,
#   11,
#   63,
#   95,
#   394,
#   227,
#   144,
#   116,
#   1,
#   69,
#   115,
#   215,
#   366,
#   2,
#   27,
#   448,
#   332,
#   22,
#   1623],
#  [1,
#   64,
#   2828,
#   10,
#   4,
#   642,
#   1005,
#   4,
#   12071,
#   5155,
#   6,
#   4,
#   4123,
#   1820,
#   36,
#   87,
#   97,
#   15656],
#  [18857, 164, 54, 2224, 11, 2044, 15657, 7889, 18858, 29, 69, 3630, 83, 10110],
#  [39949, 26, 1, 60, 117, 1, 66, 95, 346],
#  [2159, 21, 39950, 154, 253, 5, 2788],
#  [24758, 1, 59, 1, 292, 49, 415, 1113, 5743],
#  [76, 28, 73, 5, 454, 393, 117, 1, 66, 87],
#  [18859, 7, 1556, 199, 138],
#  [466, 87, 597, 2, 37, 74, 87, 430, 96, 70, 133, 69, 142],
#  [24759,
#   3,
#   397,
#   7,
#   1772,
#   25,
#   5525,
#   236,
#   39951,
#   1096,
#   33,
#   285,
#   148,
#   58,
#   459,
#   29,
#   63,
#   3,
#   444,
#   5526,
#   26,
#   236],
#  [2633,
#   15658,
#   5,
#   3242,
#   54,
#   87,
#   3141,
#   8819,
#   74,
#   37,
#   19,
#   194,
#   9,
#   74,
#   4,
#   7462,
#   321,
#   39952,
#   56],
#  [39953,
#   88,
#   915,
#   31,
#   39954,
#   85,
#   39955,
#   6760,
#   11,
#   5,
#   39956,
#   39957,
#   26,
#   19,
#   135,
#   22,
#   2142,
#   17,
#   33,
#   30],
#  [39958, 166],
#  [832, 994, 87, 329],
#  [15659, 13, 79, 2, 22, 4, 28, 7059, 5319, 74, 297, 688, 53, 6, 2548],
#  [39959, 24760, 1, 81, 456, 1323, 222, 7, 68, 67, 9, 11, 109, 672, 155, 104],
#  [5,
#   39960,
#   12,
#   3,
#   39961,
#   39962,
#   463,
#   7060,
#   11,
#   5,
#   1101,
#   443,
#   25,
#   12072,
#   1025,
#   258,
#   3046,
#   1433,
#   39963,
#   271,
#   1,
#   25,
#   229,
#   23,
#   43],
#  [1056, 19, 47, 2, 90, 5320, 13, 3, 1282, 126, 8, 3, 92, 73, 24761, 155, 104],
#  [42,
#   4,
#   328,
#   344,
#   6,
#   1,
#   77,
#   71,
#   2425,
#   211,
#   39,
#   132,
#   217,
#   39964,
#   6,
#   324,
#   196,
#   29,
#   45],
#  [47, 2, 39965, 155, 1949],
#  [23, 3, 689, 8820],
#  [1, 60, 94, 2, 6466],
#  [1977, 24762],
#  [1302, 1, 8821, 901, 4995, 331, 1833, 5156, 1, 551, 64, 11, 1950, 418, 50],
#  [141, 39966, 6467],
#  [815,
#   371,
#   24763,
#   2750,
#   24764,
#   39967,
#   5744,
#   24764,
#   4,
#   12073,
#   15660,
#   21,
#   39968,
#   3143,
#   4123],
#  [6468,
#   100,
#   39969,
#   10975,
#   11,
#   1327,
#   15661,
#   6,
#   26,
#   7463,
#   16,
#   4,
#   219,
#   6761,
#   320],
#  [39970, 1401, 32, 3, 267, 1994, 7, 785, 810, 57, 240, 7, 59, 55, 1, 81],
#  [1883, 4, 2080, 295],
#  [1228, 552, 18860],
#  [15, 18861, 3863, 255],
#  [39, 149, 56, 39971, 5, 39972],
#  [24765, 699, 70, 104, 13531, 252],
#  [39973, 1, 365, 29, 21, 54, 7061, 13, 18, 1, 81, 7, 426, 420],
#  [39974, 24, 556, 82, 10, 3, 3092],
#  [24766,
#   216,
#   19,
#   119,
#   296,
#   10,
#   3,
#   6207,
#   240,
#   14,
#   59,
#   13532,
#   13,
#   3864,
#   1144,
#   1185,
#   810,
#   45,
#   10,
#   3,
#   5321,
#   2,
#   39975],
#  [5322,
#   392,
#   533,
#   181,
#   1287,
#   6208,
#   3,
#   286,
#   1694,
#   10,
#   39976,
#   666,
#   1603,
#   20,
#   128,
#   4,
#   397,
#   1817,
#   21,
#   3416,
#   833,
#   1186],
#  [3308, 304, 154, 48, 4, 1003, 453],
#  [220, 2, 8309, 1, 382, 2270, 4023, 6, 26, 47, 2, 173, 391],
#  [15662, 471, 341, 2549, 7, 16, 4, 119, 129, 39977, 874, 72, 17, 1667],
#  [346,
#   25,
#   1025,
#   426,
#   281,
#   22,
#   1025,
#   13,
#   602,
#   816,
#   2119,
#   14,
#   133,
#   757,
#   105,
#   202,
#   1,
#   257],
#  [39978, 163, 7, 1, 64, 20, 544, 41, 684],
#  [39979, 395, 2343, 82, 5, 437, 139, 145, 22, 331, 500, 1821, 184, 23, 372],
#  [13533, 150, 24, 493, 61, 33, 248, 17],
#  [4124, 2547, 39980, 8, 5, 654, 143, 8, 3, 173],
#  [39981, 166, 18, 756, 427, 1343, 47, 2, 131, 67, 7, 162, 256],
#  [9,
#   276,
#   14,
#   111,
#   85,
#   1,
#   212,
#   23,
#   5,
#   219,
#   65,
#   67,
#   5,
#   2225,
#   9397,
#   12074,
#   1303,
#   8,
#   3358,
#   15663,
#   227,
#   42,
#   50,
#   2,
#   2045,
#   3,
#   1711],
#  [39982, 386, 18862, 165, 1, 16, 9, 673, 13, 4, 10111, 13, 3, 783],
#  [481, 50, 10, 140, 70, 717, 448, 6, 262, 13, 436, 15, 28, 73, 1103],
#  [328, 30, 1, 46, 7, 807],
#  [39983,
#   5,
#   24767,
#   275,
#   218,
#   271,
#   1,
#   25,
#   2679,
#   148,
#   79,
#   2,
#   22,
#   129,
#   7,
#   8310,
#   168,
#   18863,
#   133,
#   39984],
#  [2226,
#   1222,
#   37,
#   258,
#   3039,
#   5745,
#   86,
#   3,
#   1557,
#   173,
#   713,
#   11,
#   3,
#   3047,
#   1044,
#   303,
#   186,
#   2,
#   2680,
#   39,
#   398,
#   56,
#   39985,
#   303,
#   74,
#   11,
#   39986,
#   2319],
#  [459, 1637, 2829, 96, 620, 2, 140],
#  [141,
#   3,
#   18864,
#   100,
#   60,
#   203,
#   14,
#   90,
#   5,
#   7062,
#   1328,
#   19,
#   265,
#   1,
#   6469,
#   55,
#   1,
#   125,
#   134],
#  [92, 73, 25, 474, 173, 1108, 35, 3, 742, 17, 9398, 1510],
#  [39987,
#   471,
#   82,
#   3093,
#   9,
#   8,
#   230,
#   200,
#   17,
#   1,
#   245,
#   48,
#   2,
#   496,
#   5,
#   274,
#   3865,
#   1,
#   182,
#   44,
#   9,
#   107],
#  [8, 569, 255, 11, 43, 189],
#  [39988, 106, 2248, 1, 1369, 5, 1194, 5527],
#  [39989, 10112, 131, 486, 14, 4, 765, 244, 49],
#  [1, 46, 5, 1084],
#  [2344, 3, 2021, 18865, 772, 15664, 29, 33, 3, 24768],
#  [2022,
#   1951,
#   3,
#   279,
#   447,
#   32,
#   40,
#   11,
#   562,
#   684,
#   974,
#   9,
#   62,
#   131,
#   775,
#   175,
#   289,
#   24,
#   2517,
#   175,
#   18866,
#   1295,
#   45],
#  [310, 37, 2, 3, 677, 1452, 4, 120, 266, 129, 344, 2724, 39990, 942],
#  [39991, 1, 101, 61, 31, 2, 3, 15665, 60, 698],
#  [9399,
#   7,
#   247,
#   4,
#   250,
#   577,
#   9399,
#   7,
#   60,
#   4725,
#   14,
#   3,
#   1370,
#   25,
#   135,
#   22,
#   5,
#   272,
#   1521,
#   82,
#   10,
#   188,
#   114,
#   2,
#   14,
#   9399],
#  [230, 179, 25, 47, 2, 3, 694, 18, 947, 1344, 9, 58, 7063],
#  [8,
#   128,
#   4,
#   39992,
#   6470,
#   1137,
#   4462,
#   18867,
#   36,
#   2877,
#   10,
#   559,
#   242,
#   7,
#   6,
#   41,
#   7464,
#   335],
#  [13534, 1, 247, 3, 3562, 107, 27, 50, 2, 1597, 395],
#  [83, 168, 919, 4125, 11, 3, 2023, 951, 61, 1273, 31, 54, 134, 88, 168, 39993],
#  [39994, 348, 200, 6, 82, 10, 194, 27],
#  [39995, 49, 53, 139, 3563, 8822],
#  [1, 16, 2, 44, 5, 1087, 632, 18, 1, 167, 77, 5528, 15666],
#  [39996, 7, 287, 14],
#  [39997, 9400, 403, 243, 152],
#  [39998, 82, 10, 438, 39999],
#  [8, 15, 265, 143, 3798, 109, 38, 201, 38, 21, 201],
#  [3243, 435, 3358, 296, 10, 1097, 49, 1, 62, 77, 9, 2, 22, 2024, 3948],
#  [935, 9, 498, 344, 75, 179],
#  [23, 3, 1229, 40000, 2081],
#  [1,
#   25,
#   47,
#   2,
#   37,
#   2,
#   2681,
#   18,
#   330,
#   17,
#   5,
#   780,
#   710,
#   66,
#   102,
#   521,
#   123,
#   4,
#   322,
#   85,
#   1,
#   220,
#   409,
#   1210,
#   40001,
#   7465,
#   5529,
#   553,
#   1049],
#  [40002,
#   1,
#   69,
#   376,
#   1,
#   330,
#   7,
#   13,
#   93,
#   457,
#   27,
#   335,
#   12,
#   817,
#   211,
#   35,
#   7,
#   47,
#   19,
#   15,
#   124,
#   1,
#   350,
#   2393],
#  [40003, 82, 2160],
#  [40004, 54, 12, 206, 327, 5746],
#  [39, 149, 56, 40005, 5, 710, 3799, 479, 11, 1064, 177, 1743, 1, 46, 7],
#  [40006,
#   84,
#   1,
#   90,
#   7,
#   45,
#   1,
#   517,
#   3,
#   968,
#   1645,
#   4591,
#   258,
#   41,
#   1104,
#   1416,
#   13,
#   5,
#   625,
#   538,
#   6,
#   63,
#   6209,
#   319],
#  [40007, 971, 1507, 1199, 13, 41, 5530, 2365, 10, 3046, 2190, 744, 76, 3048],
#  [76, 161, 40008, 8, 3417, 13, 3, 12075, 4463, 13535, 39, 132, 217, 40009],
#  [24769, 4854, 1, 117, 3309, 168, 45],
#  [40010, 138, 24, 16, 40011, 2999, 79, 40012, 17, 22],
#  [27, 8, 5, 78, 2023, 39, 1434, 56, 40013],
#  [40014,
#   419,
#   11,
#   10,
#   186,
#   469,
#   12,
#   4,
#   2789,
#   273,
#   27,
#   78,
#   24770,
#   2449,
#   124,
#   7,
#   35,
#   181,
#   15,
#   91,
#   1287,
#   351,
#   53,
#   3,
#   10113],
#  [24771, 88, 426, 35, 86, 3, 8311, 83, 94, 2, 367, 86, 76],
#  [9401, 1, 5531, 1, 108, 416, 6, 206, 40015, 167, 16, 621, 24772],
#  [141, 188, 40016, 7466, 682, 253, 40017],
#  [40018, 97],
#  [40019],
#  [4851, 24773, 116, 794, 7, 523, 11, 1276, 39, 442, 56, 231, 40020],
#  [40021, 19, 1845, 2, 806],
#  [70, 4, 344, 6, 682, 48, 43, 23, 4024, 2725],
#  [363, 2191, 33, 2601],
#  [40022, 161, 72, 88, 145, 67, 9, 88, 426, 718, 793],
#  [4855,
#   223,
#   47,
#   13,
#   63,
#   3800,
#   144,
#   547,
#   18,
#   4592,
#   8,
#   4,
#   24774,
#   58,
#   4225,
#   3866,
#   10,
#   7,
#   26,
#   223,
#   2602,
#   457,
#   2830],
#  [141, 3949, 4025, 25, 40023, 711],
#  [116,
#   139,
#   1,
#   22,
#   5747,
#   218,
#   249,
#   6759,
#   340,
#   10976,
#   1,
#   44,
#   24,
#   38,
#   4464,
#   38,
#   17],
#  [54,
#   651,
#   3,
#   4126,
#   718,
#   43,
#   1,
#   66,
#   2909,
#   8312,
#   3,
#   4127,
#   4350,
#   258,
#   4,
#   219,
#   6471,
#   26,
#   72,
#   9,
#   113,
#   7467,
#   961],
#  [1177,
#   164,
#   312,
#   10,
#   3,
#   322,
#   2,
#   31,
#   52,
#   15,
#   1,
#   37,
#   233,
#   3,
#   3049,
#   277,
#   40024,
#   1088,
#   17,
#   9,
#   550,
#   76,
#   40],
#  [8, 47, 2, 22, 1039, 10, 109, 931, 103],
#  [40025, 883, 262, 225, 346, 104, 626, 1563],
#  [18868,
#   15,
#   26,
#   418,
#   50,
#   110,
#   263,
#   23,
#   9,
#   110,
#   550,
#   38,
#   295,
#   38,
#   110,
#   69,
#   1520,
#   9,
#   6,
#   100,
#   36,
#   378,
#   10,
#   9,
#   306,
#   110,
#   100,
#   3,
#   15667,
#   26,
#   119,
#   111],
#  [18869,
#   1695,
#   527,
#   89,
#   2,
#   658,
#   10,
#   54,
#   2,
#   54,
#   21,
#   3867,
#   10,
#   4,
#   177,
#   1089,
#   10977,
#   4996],
#  [40026, 40027, 12076, 24, 3000, 2, 7, 9402, 40028, 18870, 40029, 636, 189],
#  [40030, 129, 99, 803],
#  [925, 1, 151, 40031, 197, 628, 179, 6, 2344, 5, 933],
#  [24775,
#   1,
#   43,
#   23,
#   4,
#   238,
#   3044,
#   11,
#   10978,
#   6,
#   374,
#   240,
#   7,
#   131,
#   67,
#   9,
#   10,
#   352,
#   18,
#   42,
#   24,
#   11,
#   1847],
#  [40032, 17, 275, 55, 520, 12, 467, 44, 7, 16, 1, 785, 5, 783, 11, 10, 4128],
#  [40033, 57, 53, 31, 148, 74, 241, 14, 15668],
#  [8, 29, 10, 4, 40034, 2120],
#  [40035,
#   84,
#   6,
#   53,
#   59,
#   1,
#   25,
#   20,
#   2910,
#   688,
#   3,
#   18871,
#   118,
#   76,
#   520,
#   12,
#   24,
#   237,
#   2,
#   131,
#   89,
#   86,
#   15669,
#   73,
#   73],
#  [1, 34, 3, 787, 25, 98, 18, 1, 81, 4026, 21, 4, 791, 8, 138],
#  [58, 580, 262, 2, 44, 40, 58, 255, 1, 108, 34, 188, 13, 648],
#  [2345, 40036, 144, 28, 65, 334, 90, 7, 45, 74, 430, 1848],
#  [40037, 1, 16, 4, 4129, 2, 627],
#  [5748,
#   18,
#   114,
#   460,
#   10,
#   3950,
#   106,
#   266,
#   70,
#   668,
#   1522,
#   106,
#   15,
#   24,
#   7064,
#   1011,
#   266,
#   33,
#   5,
#   40038,
#   1,
#   1168,
#   1054,
#   4,
#   2394,
#   12,
#   2450,
#   15670,
#   26,
#   87,
#   2790],
#  [11, 5, 4997],
#  [15671,
#   1902,
#   259,
#   110,
#   147,
#   60,
#   678,
#   956,
#   49,
#   6,
#   63,
#   3,
#   5532,
#   505,
#   144,
#   968,
#   1250,
#   151,
#   2,
#   22,
#   3,
#   54,
#   185,
#   330,
#   130],
#  [40039, 2952, 1749],
#  [4593, 133, 177, 9403, 2082, 35, 21, 3, 363],
#  [1, 64, 558, 26, 18, 1178, 533, 15672],
#  [1056, 5, 1781, 696, 14, 3, 333, 26, 19, 801, 213, 130],
#  [40040, 63, 2, 318, 2, 40041, 105, 24776, 450, 10, 2451, 40042, 40043, 4226],
#  [40044, 302, 1773, 199, 28, 460, 51, 3, 7468],
#  [24777,
#   24778,
#   166,
#   749,
#   1803,
#   6472,
#   258,
#   109,
#   4726,
#   122,
#   90,
#   7,
#   2751,
#   6,
#   7469,
#   672],
#  [1, 62, 77, 2, 43, 40],
#  [8313, 10114, 125, 7, 67, 185, 20, 24779, 7, 15, 200, 37, 417],
#  [24780, 36, 87, 40045],
#  [846, 77, 2, 37, 52, 232, 107],
#  [15, 42, 1125, 4727, 138, 37, 2, 140, 26, 152, 103],
#  [18872,
#   445,
#   262,
#   2,
#   44,
#   11,
#   7890,
#   9404,
#   19,
#   587,
#   12,
#   130,
#   88,
#   139,
#   131,
#   52,
#   2,
#   4594,
#   6,
#   37,
#   2,
#   3,
#   450],
#  [40, 677, 700, 160, 677, 2, 790, 9405, 7065, 26, 3352],
#  [40046, 1, 108, 7, 1, 16, 4, 174, 30, 40, 86, 76],
#  [40047,
#   40048,
#   18,
#   58,
#   124,
#   2,
#   287,
#   7,
#   24,
#   418,
#   54,
#   429,
#   2,
#   335,
#   2,
#   14,
#   18,
#   58,
#   175,
#   13,
#   9,
#   49],
#  [708, 3244, 5, 322, 95, 394, 504, 779, 9, 2392, 10, 195, 103],
#  [40049, 142, 55, 256, 35, 7, 11, 26],
#  [1, 90, 1084, 6, 1288, 117, 88, 1656, 32, 12, 640, 188, 80, 8, 854, 425, 130],
#  [4725,
#   62,
#   77,
#   2,
#   37,
#   2,
#   43,
#   77,
#   2,
#   115,
#   11,
#   6,
#   44,
#   13536,
#   262,
#   3245,
#   170,
#   719,
#   93,
#   61,
#   37],
#  [19, 141, 27, 610, 1849, 768, 568, 11, 8314, 1, 117, 1, 25, 158],
#  [15673, 166, 1773, 1, 81, 41, 129, 18, 131, 13, 41, 51, 3712],
#  [40050, 1995, 166, 110, 8],
#  [5323, 4985, 1, 292, 92, 3094, 18, 253, 3, 178, 978, 25, 9, 98],
#  [15674, 1, 90, 7],
#  [120, 1935, 30, 5, 1288, 8, 11, 4351],
#  [175,
#   314,
#   7066,
#   12,
#   900,
#   640,
#   13537,
#   8,
#   1333,
#   364,
#   634,
#   74,
#   156,
#   3493,
#   6210,
#   4998],
#  [877,
#   40051,
#   40052,
#   13538,
#   15675,
#   80,
#   422,
#   1920,
#   658,
#   6211,
#   65,
#   1821,
#   856,
#   273,
#   1117,
#   40053,
#   4728,
#   40054],
#  [13539, 3, 92, 484, 91, 46, 2101],
#  [4352, 2, 316, 435, 255, 6, 333, 417, 80, 33, 30, 40055],
#  [40056, 1, 415, 727],
#  [40057, 82, 880, 6, 259, 550, 10, 7, 16, 95, 3713, 999],
#  [40058,
#   3359,
#   1,
#   330,
#   41,
#   778,
#   6,
#   3,
#   10979,
#   13,
#   2546,
#   8,
#   175,
#   13,
#   9,
#   26,
#   1145,
#   41,
#   4027],
#  [40059, 1725],
#  [1, 16, 4, 8315, 453],
#  [40060, 3144, 1264, 76, 2393, 4999, 34, 1636, 3631, 2320],
#  [1385,
#   32,
#   2,
#   5,
#   323,
#   10,
#   192,
#   357,
#   14,
#   108,
#   4729,
#   161,
#   85,
#   1,
#   25,
#   1072,
#   6,
#   1616,
#   85,
#   1,
#   25,
#   1132,
#   1,
#   60,
#   46,
#   27,
#   1822],
#  [8, 1866, 23, 274, 64, 21, 18873, 65, 65, 3801, 1, 46, 326, 1108],
#  [40061,
#   13540,
#   56,
#   1,
#   117,
#   9406,
#   25,
#   459,
#   9,
#   134,
#   19,
#   511,
#   2,
#   10980,
#   40062,
#   331,
#   964,
#   34,
#   40063,
#   6,
#   15676],
#  [15677,
#   9,
#   144,
#   4,
#   119,
#   28,
#   979,
#   62,
#   59,
#   79,
#   1,
#   125,
#   9,
#   1,
#   145,
#   127,
#   4,
#   309,
#   15678,
#   667,
#   902,
#   23,
#   15679,
#   13,
#   4130],
#  [1, 94, 2, 127, 432, 1, 151, 188, 537, 86, 4, 1482],
#  [40064,
#   31,
#   608,
#   393,
#   4,
#   30,
#   549,
#   321,
#   2518,
#   56,
#   431,
#   7,
#   552,
#   187,
#   7,
#   35,
#   13,
#   3,
#   583,
#   105,
#   606,
#   1131],
#  [10115, 1636, 598, 5749, 824, 676, 32, 12, 2550, 4595],
#  [560, 54, 12, 5, 611, 2161, 48, 1624, 11, 3, 1657],
#  [2911, 179, 115, 10, 4, 309, 1179, 222, 43, 2083],
#  [359,
#   97,
#   209,
#   66,
#   4,
#   98,
#   157,
#   23,
#   3,
#   316,
#   184,
#   544,
#   2192,
#   24781,
#   368,
#   3,
#   18874,
#   21,
#   24782,
#   25,
#   3,
#   4730],
#  [15,
#   126,
#   25,
#   992,
#   12,
#   112,
#   28,
#   2,
#   1335,
#   21,
#   33,
#   5,
#   201,
#   222,
#   27,
#   162,
#   146,
#   1027,
#   6,
#   7891,
#   35,
#   4028,
#   5,
#   15680,
#   135,
#   908],
#  [24783,
#   268,
#   12,
#   5750,
#   120,
#   21,
#   40065,
#   436,
#   358,
#   40066,
#   25,
#   13,
#   1545,
#   628,
#   18875,
#   9407,
#   263,
#   28,
#   134,
#   2366,
#   6473,
#   28,
#   1350],
#  [667, 33, 127, 304, 975, 40],
#  [40067, 1, 44, 17, 33, 3, 50],
#  [40068,
#   19,
#   113,
#   194,
#   3,
#   178,
#   1362,
#   15,
#   122,
#   22,
#   52,
#   123,
#   3,
#   396,
#   12,
#   553,
#   6,
#   19,
#   113,
#   441,
#   74,
#   40069,
#   218,
#   19,
#   537],
#  [20, 203, 27, 246, 263, 60, 200],
#  [40070,
#   153,
#   499,
#   14,
#   41,
#   24784,
#   1055,
#   887,
#   799,
#   1033,
#   6,
#   5,
#   713,
#   68,
#   340,
#   13,
#   17],
#  [54,
#   12,
#   3,
#   4125,
#   8,
#   181,
#   71,
#   24785,
#   15681,
#   144,
#   33,
#   122,
#   180,
#   18,
#   240,
#   14,
#   18876,
#   7,
#   5,
#   7470,
#   12077,
#   8,
#   175,
#   3310],
#  [40071, 7471, 75, 95, 1921, 1, 67],
#  [5000, 2, 7892, 228, 2, 190, 3, 974, 277, 40],
#  [8, 311, 95, 7893, 2227],
#  [18877, 1, 62, 59, 185, 15682, 185, 9, 25, 5, 490, 2, 16, 3189, 375],
#  [733, 38, 249, 38, 121, 16, 23, 369, 3418, 14, 6, 572, 14, 2, 16, 4, 28, 30],
#  [120, 1057, 30, 2, 33, 3, 617, 1034, 32, 83],
#  [148, 185, 180, 5751, 3311, 428, 769, 14],
#  [120, 272, 40072, 163, 7, 10, 188, 7, 1, 101, 7, 57, 390, 3, 30, 4, 315],
#  [40073,
#   40074,
#   24,
#   15,
#   1845,
#   2,
#   407,
#   414,
#   19,
#   824,
#   34,
#   24786,
#   12,
#   638,
#   20,
#   26],
#  [40075, 1, 25, 4, 132, 45, 1668],
#  [40076, 106, 105, 227, 110, 125, 24, 1951, 110, 509, 2, 22, 3312, 196, 33],
#  [84, 38, 7, 48, 303, 1021, 1417, 14, 40077, 38],
#  [40078, 9408, 167, 7, 90, 14, 1, 90, 7],
#  [40079, 153, 966, 195, 100, 102, 14, 175, 40],
#  [24787, 16, 112, 101, 2, 67, 7, 277],
#  [1,
#   151,
#   85,
#   41,
#   355,
#   568,
#   34,
#   199,
#   743,
#   6,
#   41,
#   32,
#   6,
#   96,
#   53,
#   31,
#   4,
#   605,
#   872,
#   558,
#   107],
#  [78, 40080, 245, 1, 68, 343, 5324, 15683, 1165],
#  [404,
#   129,
#   690,
#   1006,
#   17,
#   61,
#   168,
#   45,
#   698,
#   2,
#   67,
#   133,
#   130,
#   23,
#   3,
#   589,
#   6,
#   1336,
#   24788,
#   26,
#   42,
#   50,
#   2,
#   1296,
#   244,
#   825],
#  [40081, 334, 53, 66, 205, 5977, 79, 114, 25, 9],
#  [40082, 40083, 62, 22, 111, 1, 182, 131, 662, 7, 1, 90, 41, 483],
#  [46, 5, 18878, 155, 104, 18, 1, 81, 1, 1646, 9, 29],
#  [1557,
#   174,
#   40084,
#   163,
#   53,
#   70,
#   766,
#   5533,
#   18,
#   3,
#   2634,
#   8,
#   1386,
#   2912,
#   13541,
#   61,
#   68,
#   44,
#   4,
#   803,
#   13,
#   53,
#   45],
#  [10116, 1, 62, 108, 28, 1177, 164],
#  [234, 73, 92, 73, 155, 104, 1, 46, 5, 494],
#  [2346, 345, 1, 3095, 595, 2913, 105, 4, 1200, 407],
#  [20, 48, 80, 51, 4, 129, 570, 459, 963, 96, 47, 2, 67, 5, 1785],
#  [18879, 82, 10, 8316, 28, 329],
#  [4856, 1, 117, 110, 25, 46, 193, 316, 18, 829, 193, 18880, 841, 353, 347],
#  [78,
#   849,
#   1224,
#   8,
#   234,
#   1,
#   169,
#   142,
#   2,
#   67,
#   9,
#   18,
#   70,
#   24,
#   32,
#   360,
#   2579,
#   186,
#   30,
#   160,
#   5,
#   272,
#   15,
#   70,
#   34,
#   4,
#   1936],
#  [40085, 163, 7],
#  [40086, 6, 40087, 1, 64, 15, 587, 101, 1450, 16, 4, 1564],
#  [15684, 49, 2791, 203, 17, 12078, 150, 28],
#  [24789,
#   1,
#   59,
#   55,
#   7,
#   382,
#   65,
#   3,
#   40088,
#   100,
#   17,
#   1786,
#   132,
#   12,
#   24790,
#   3096,
#   17,
#   276,
#   9,
#   112,
#   7,
#   94,
#   2,
#   16,
#   4,
#   591,
#   12,
#   95,
#   24791,
#   214],
#  [40089,
#   521,
#   29,
#   40090,
#   86,
#   110,
#   25,
#   3,
#   54,
#   2,
#   538,
#   3,
#   114,
#   460,
#   55,
#   4,
#   2993,
#   110,
#   25],
#  [6460, 392],
#  [1, 117, 110, 25, 75, 21, 5534, 6, 5, 1222],
#  [8,
#   179,
#   12,
#   27,
#   422,
#   346,
#   4731,
#   441,
#   10,
#   4227,
#   18881,
#   1,
#   24792,
#   24793,
#   40091,
#   84,
#   40092,
#   8823],
#  [69, 376, 19, 128, 416, 3, 146, 1, 16, 379, 597],
#  [154,
#   204,
#   5,
#   173,
#   24,
#   91,
#   533,
#   1,
#   68,
#   44,
#   26,
#   60,
#   13542,
#   3564,
#   23,
#   186,
#   1,
#   101,
#   88,
#   240,
#   14,
#   500,
#   54],
#  [40093, 223, 24794],
#  [40094, 40095, 246, 17, 203, 14, 903],
#  [15685,
#   74,
#   44,
#   877,
#   20,
#   388,
#   2102,
#   16,
#   2,
#   1246,
#   484,
#   503,
#   712,
#   5,
#   10117,
#   78,
#   2914,
#   6,
#   131,
#   80,
#   266,
#   31,
#   224,
#   156,
#   225,
#   205,
#   3360],
#  [239,
#   159,
#   307,
#   339,
#   1201,
#   65,
#   113,
#   104,
#   159,
#   43,
#   1558,
#   11,
#   967,
#   7,
#   350,
#   2025,
#   133,
#   3,
#   746,
#   74,
#   430,
#   19,
#   4,
#   177,
#   296],
#  [24795, 25, 4, 129, 1726, 673, 258, 7, 299, 101, 7, 68, 127, 9, 32, 13, 999],
#  [47, 2, 67, 40096, 40097, 11, 13543, 274, 6, 4, 478, 221, 191, 9, 8, 28],
#  [75, 2682, 401, 793, 99, 60, 24, 1444, 2, 37, 2, 5001, 126, 1396],
#  [19, 580, 88, 62, 1694, 14],
#  [10118, 302, 18882, 79, 8, 9, 34, 188, 1930, 33, 133, 3, 308],
#  [66, 112, 814, 32, 21, 71, 243, 3194, 201, 6, 2602, 193, 2144, 325, 30],
#  [40098, 7, 167, 72, 7, 324, 130, 6, 31, 4, 6474, 2, 3050, 32],
#  [829, 2321, 19, 415, 2249, 39, 132, 217, 40099],
#  [1553,
#   70,
#   135,
#   22,
#   24796,
#   23,
#   5,
#   786,
#   10119,
#   103,
#   73,
#   344,
#   73,
#   6,
#   200,
#   164,
#   23,
#   4857,
#   13,
#   359,
#   55,
#   4,
#   157,
#   980],
#  [39,
#   24797,
#   56,
#   40100,
#   1227,
#   40101,
#   8317,
#   3,
#   1386,
#   1032,
#   5978,
#   70,
#   24,
#   91,
#   820,
#   3361,
#   102,
#   435,
#   424],
#  [24798,
#   40102,
#   284,
#   3,
#   210,
#   1,
#   16,
#   36,
#   211,
#   2,
#   3145,
#   78,
#   1696,
#   105,
#   7894,
#   40103,
#   40104,
#   39,
#   398,
#   56,
#   40105],
#  [2060,
#   10,
#   3,
#   250,
#   3951,
#   734,
#   36,
#   619,
#   1337,
#   10,
#   156,
#   159,
#   5,
#   52,
#   492,
#   12,
#   2915,
#   6762,
#   1638,
#   42,
#   10,
#   4,
#   28,
#   427,
#   1,
#   257],
#  [40106, 98, 1326, 4131, 139, 22, 205, 54, 11, 3, 1968, 974, 959, 49],
#  [40107,
#   236,
#   53,
#   696,
#   418,
#   600,
#   21,
#   1511,
#   40108,
#   236,
#   1,
#   66,
#   4,
#   1511,
#   18,
#   9,
#   220,
#   229,
#   1133,
#   1,
#   167,
#   34,
#   53,
#   1418],
#  [40109, 198, 560, 116, 69, 1, 59],
#  [3097, 8, 32, 26, 6, 70, 1804, 1, 46, 796, 19, 47, 2, 31, 9, 51, 2347, 277],
#  [236, 1, 542, 3, 379, 782, 269, 63, 130],
#  [1677, 291, 77, 14, 21, 109, 23, 2792],
#  [40110, 290, 41, 40111, 16, 4, 654],
#  [24799, 84, 17, 6475, 9, 1, 248, 41, 3419, 20, 943, 2793, 407],
#  [40112,
#   40113,
#   1,
#   117,
#   1,
#   145,
#   176,
#   3,
#   2010,
#   10,
#   17,
#   484,
#   18,
#   1,
#   20,
#   10120,
#   9,
#   51,
#   24800],
#  [40114, 3802, 182, 1023, 21, 14],
#  [24801, 40115, 65, 1787, 1377, 5, 268],
#  [24802,
#   405,
#   1,
#   117,
#   24,
#   113,
#   169,
#   1,
#   1304,
#   9,
#   5,
#   1669,
#   169,
#   300,
#   9,
#   546,
#   1,
#   121,
#   16,
#   2,
#   1820,
#   403,
#   49],
#  [13,
#   3,
#   136,
#   2,
#   40116,
#   21,
#   40117,
#   2,
#   496,
#   40118,
#   139,
#   22,
#   28,
#   372,
#   18,
#   60,
#   117,
#   40119,
#   25,
#   21,
#   196,
#   90,
#   109],
#  [7472, 40120, 14, 45, 143, 25, 1497, 6, 7, 145, 287, 3, 2916, 48, 2, 109],
#  [20, 2162, 23, 3, 98, 294, 154, 1850, 51, 7067, 1217, 790, 324],
#  [334, 4228, 9409, 3632, 8, 2603],
#  [759, 12, 2271, 58, 1378, 10, 109],
#  [658, 50, 10, 14],
#  [116, 8, 13544, 15, 660, 983],
#  [76, 27, 8, 474, 9, 8, 26, 466, 1978, 6, 58, 435, 179, 815],
#  [100, 347, 2, 24803, 10, 3, 30, 47, 2, 176, 492, 3868, 12, 3, 774],
#  [9410,
#   1116,
#   4,
#   444,
#   315,
#   87,
#   399,
#   8824,
#   17,
#   121,
#   2794,
#   13,
#   3,
#   7068,
#   20,
#   218,
#   70,
#   40121,
#   499,
#   14,
#   5,
#   364,
#   85,
#   9,
#   6476,
#   1453],
#  [40122,
#   643,
#   22,
#   52,
#   27,
#   157,
#   2,
#   233,
#   32,
#   777,
#   65,
#   67,
#   3,
#   78,
#   857,
#   279,
#   40123,
#   24804],
#  [69, 142, 2, 22, 204, 21, 1017, 556, 10981, 6, 2683],
#  [80, 51, 152, 75, 183, 18, 24, 86, 114, 86, 299, 2795],
#  [40124, 1453, 1589, 7, 45],
#  [1, 60, 94, 4, 320],
# ...
#  [345, 3, 5540, 22, 21, 7],
#  [1, 1182, 151, 85, 148, 44, 27, 18, 667, 605, 19, 89],
#  [632, 1419, 371],
#  [40220, 19, 18898],
#  [40221, 124, 9417, 1, 465, 41, 99, 462, 17, 7, 378],
#  [573, 1, 20, 69, 376, 17, 11, 4, 309, 159, 150, 514, 93, 284, 338, 15, 111],
#  [4133,
#   98,
#   269,
#   18,
#   24,
#   3,
#   3875,
#   24849,
#   1317,
#   223,
#   1436,
#   57,
#   53,
#   180,
#   18899,
#   242,
#   40222,
#   129,
#   2,
#   16,
#   53,
#   52,
#   948],
#  [28,
#   97,
#   58,
#   580,
#   49,
#   1,
#   40223,
#   29,
#   244,
#   2,
#   190,
#   4036,
#   13,
#   7479,
#   18,
#   12,
#   539,
#   1,
#   253,
#   9],
#  [40224, 144, 55, 1, 25, 215, 366, 2, 3, 379],
#  [796, 2395, 1797, 4037, 6, 237, 372, 97, 27, 8, 234],
#  [24850, 1, 1683, 20, 313, 3, 259, 210, 19, 15, 133, 9],
#  [72, 1, 313, 5, 1001, 168, 652, 9, 121, 22, 95, 9418, 24851],
#  [255, 12087, 58, 11, 1173, 216],
#  [485, 193, 865, 24852, 18, 110, 291, 77, 2, 367, 39, 442, 56, 231, 40225],
#  [1885, 40226, 40227, 40228, 40229, 4134, 40230, 154, 48, 4, 114, 197, 63, 27],
#  [1, 90, 7, 45],
#  [13, 2166, 1, 212, 29, 112, 7902, 13, 441, 52, 344, 1, 46, 9],
#  [8, 23, 817, 3876, 32, 556, 5329],
#  [42,
#   863,
#   3,
#   1728,
#   26,
#   509,
#   34,
#   1103,
#   57,
#   22,
#   229,
#   6,
#   105,
#   60,
#   424,
#   47,
#   2,
#   90,
#   187,
#   15,
#   91],
#  [18900,
#   136,
#   45,
#   1679,
#   1182,
#   40231,
#   12,
#   407,
#   2752,
#   74,
#   4595,
#   12,
#   638,
#   15,
#   74,
#   40232,
#   10,
#   41,
#   407,
#   5541],
#  [40233,
#   18901,
#   351,
#   82,
#   36,
#   1139,
#   3,
#   604,
#   66,
#   5,
#   462,
#   11,
#   9,
#   9,
#   1405,
#   34,
#   4852,
#   76,
#   166,
#   54,
#   12,
#   285,
#   1994,
#   15,
#   2197,
#   82,
#   67,
#   53,
#   816,
#   189,
#   189],
#  [47, 2, 37, 67, 29, 11, 95, 394, 21, 4, 838, 10991],
#  [8, 32, 6, 63, 244, 2, 2675, 110, 100, 2, 67, 193, 40234, 40],
#  [24853,
#   334,
#   615,
#   9419,
#   1204,
#   208,
#   4,
#   4122,
#   6484,
#   1473,
#   58,
#   47,
#   2,
#   115,
#   207,
#   2350,
#   2350,
#   5,
#   3052],
#  [8,
#   1324,
#   2,
#   176,
#   1406,
#   18902,
#   51,
#   4,
#   1230,
#   7480,
#   61,
#   297,
#   88,
#   35,
#   230,
#   5003,
#   24,
#   195,
#   55,
#   50,
#   88,
#   57,
#   2486,
#   225,
#   111],
#  [15701,
#   88,
#   35,
#   347,
#   160,
#   1,
#   12088,
#   40235,
#   6,
#   1,
#   370,
#   2,
#   241,
#   3,
#   1345,
#   17,
#   1,
#   48,
#   1029,
#   40236,
#   201],
#  [40237,
#   163,
#   7,
#   15,
#   91,
#   19,
#   47,
#   2,
#   337,
#   9,
#   5,
#   173,
#   282,
#   19,
#   4600,
#   17,
#   27,
#   57,
#   22,
#   4,
#   28,
#   641],
#  [40238, 76, 227, 71, 30, 615, 22, 480, 2, 127, 9, 32, 2, 3002, 13561, 825],
#  [15, 492, 51, 4, 2880, 969, 2061, 23, 562, 40239],
#  [23, 389, 21, 40240, 13562, 6, 4860],
#  [40, 8, 119, 295, 23, 43, 40],
#  [40241, 302, 2799, 163, 7, 10, 438, 14, 45],
#  [18903, 28, 329, 11, 3, 965, 679, 30, 10, 9],
#  [381, 2, 3147, 10992, 13, 1147, 3954, 1596, 2198, 11, 78, 2914, 344],
#  [24854, 1148, 1671, 10133],
#  [66, 34, 239, 221, 12, 2351, 92, 73, 15, 1, 408, 31, 24855, 463, 204],
#  [40242, 84, 616, 58, 124, 53, 75, 24, 197, 28],
#  [40243, 49, 20, 729, 11, 83, 2749, 22, 133, 171],
#  [70, 4, 8830, 308, 1330, 39, 714, 663, 40244],
#  [381, 2, 78, 476, 13, 3, 1788],
#  [1428,
#   302,
#   3638,
#   24856,
#   100,
#   20,
#   1053,
#   32,
#   12,
#   1298,
#   186,
#   454,
#   8831,
#   72,
#   1,
#   77,
#   9,
#   126,
#   122,
#   16,
#   2,
#   37,
#   2,
#   24857,
#   105,
#   3,
#   631,
#   40245],
#  [24858, 137, 1, 64, 255, 209, 1, 77, 5, 387, 204],
#  [236,
#   5758,
#   24859,
#   3,
#   2367,
#   13,
#   3,
#   909,
#   6766,
#   107,
#   17,
#   4986,
#   593,
#   210,
#   535,
#   74,
#   868,
#   14,
#   75,
#   3099,
#   3639],
#  [40246, 1, 498, 1981],
#  [120, 774, 2, 33],
#  [2026, 4, 18904, 2917, 5004, 6, 3363, 10, 40247, 39, 398, 56, 40248],
#  [40249, 1, 147, 59, 83, 168, 199, 40250, 252, 2953, 1205, 4, 271, 504],
#  [40251,
#   1,
#   25,
#   33,
#   18905,
#   32,
#   10134,
#   1,
#   69,
#   44,
#   9,
#   34,
#   1,
#   378,
#   2,
#   18,
#   1,
#   542,
#   9,
#   25,
#   3,
#   1868,
#   1,
#   101,
#   7,
#   66,
#   4,
#   617,
#   786,
#   2753],
#  [1, 64, 15, 15, 15, 15, 15, 255, 12, 685],
#  [40252, 70, 87, 34, 3, 487, 8, 4601, 2686],
#  [40253, 9, 8, 4355, 6, 1345, 34, 14, 237, 2, 13563, 7, 2, 206, 5542, 3796],
#  [40254, 163, 7, 1, 282],
#  [13564, 106, 227, 19, 141, 2637, 1306, 106, 266, 53, 189],
#  [24860, 20, 10, 7, 390, 39, 321, 40255, 56, 40256, 7903],
#  [40257, 295, 61, 889, 1775, 11, 866],
#  [40258,
#   44,
#   7,
#   31,
#   4352,
#   10,
#   4038,
#   3640,
#   65,
#   44,
#   61,
#   20,
#   2687,
#   2,
#   7,
#   163,
#   7,
#   15,
#   91],
#  [1, 880, 10993, 3955, 88, 20, 6767, 14, 948],
#  [40259, 153, 19, 133, 93],
#  [8832, 494, 73, 65, 7481, 235, 767, 222, 860, 238, 772],
#  [472, 5543, 40260, 2, 3, 40261, 42, 2, 242, 244],
#  [19,
#   1081,
#   3,
#   764,
#   3569,
#   2487,
#   10,
#   8327,
#   3877,
#   35,
#   1053,
#   32,
#   1,
#   62,
#   77,
#   2,
#   606,
#   1484,
#   2881,
#   10,
#   2487,
#   257,
#   122,
#   261,
#   2300],
#  [40262, 58, 75, 23, 152, 63, 2, 37, 80, 433],
#  [19,
#   188,
#   24843,
#   40,
#   27,
#   8,
#   5,
#   30,
#   1,
#   94,
#   2,
#   176,
#   9,
#   23,
#   5,
#   500,
#   4734,
#   128,
#   629,
#   8833,
#   294,
#   204,
#   178,
#   425,
#   99],
#  [47,
#   2,
#   3,
#   4341,
#   40263,
#   1625,
#   184,
#   6,
#   5,
#   78,
#   5751,
#   470,
#   12,
#   385,
#   35,
#   13,
#   3,
#   1089,
#   10994,
#   216],
#  [24, 45, 3247, 21, 5, 5759, 1, 994, 9, 2, 22, 2084, 27, 146],
#  [214,
#   1382,
#   2606,
#   13,
#   436,
#   49,
#   1803,
#   24861,
#   3641,
#   930,
#   15,
#   111,
#   85,
#   110,
#   48,
#   5981,
#   123,
#   3197],
#  [10995,
#   39,
#   149,
#   56,
#   24862,
#   119,
#   5330,
#   10,
#   71,
#   651,
#   1,
#   77,
#   2,
#   190,
#   38,
#   13565,
#   38,
#   399],
#  [19, 15, 120, 63, 700, 4, 268, 11, 95, 394],
#  [1, 75, 46, 158, 134, 985, 767, 29, 2832],
#  [18906, 7, 57, 22, 1000, 40264, 4, 527, 10, 193, 432, 5760, 28, 294],
#  [40265, 24863, 4, 7904],
#  [28, 97, 33, 1, 139, 31, 29, 911, 40266],
#  [20,
#   388,
#   186,
#   12,
#   156,
#   2688,
#   818,
#   27,
#   146,
#   40267,
#   191,
#   118,
#   26,
#   469,
#   18,
#   58,
#   569,
#   120,
#   5,
#   489,
#   3956,
#   14],
#  [40268,
#   42,
#   475,
#   2272,
#   2552,
#   8,
#   4231,
#   356,
#   40269,
#   15702,
#   1500,
#   1,
#   59,
#   3,
#   5544],
#  [421, 6485, 24864, 6486, 21, 5, 40270, 1536, 7482, 3494, 3494, 5, 611],
#  [1474, 6203, 266, 13566, 8, 103, 73, 42, 113, 925, 40],
#  [47, 32, 2, 2316],
#  [40271, 19, 441, 7, 29, 13, 17],
#  [33, 3, 3878, 148, 23, 43, 35, 47, 2, 127, 14, 3878, 45],
#  [40272,
#   44,
#   7,
#   59,
#   185,
#   57,
#   22,
#   2229,
#   10,
#   898,
#   19,
#   544,
#   158,
#   11,
#   2833,
#   1,
#   25,
#   215,
#   366,
#   2,
#   544,
#   1645,
#   730],
#  [19,
#   181,
#   4,
#   288,
#   260,
#   11,
#   3,
#   162,
#   1406,
#   159,
#   1,
#   81,
#   19,
#   135,
#   261,
#   27,
#   4735,
#   39,
#   18907,
#   56,
#   40273,
#   380,
#   294],
#  [10996, 82, 150, 3, 178, 54, 2, 117, 14, 4, 120, 1057, 30],
#  [1353,
#   2,
#   37,
#   96,
#   4736,
#   96,
#   464,
#   4,
#   235,
#   17,
#   57,
#   574,
#   5,
#   191,
#   231,
#   417,
#   3,
#   5982,
#   18908,
#   35,
#   52,
#   341,
#   534],
#  [796,
#   1,
#   101,
#   7,
#   31,
#   41,
#   1066,
#   52,
#   29,
#   13,
#   41,
#   778,
#   122,
#   22,
#   15,
#   111,
#   72,
#   7,
#   62],
#  [48, 4, 78, 1035, 659],
#  [40274, 10135, 13567, 40275, 242, 7, 33, 1, 69, 31, 87, 213, 5164],
#  [18909,
#   2882,
#   37,
#   2,
#   3,
#   2689,
#   694,
#   278,
#   4,
#   497,
#   127,
#   4,
#   590,
#   1416,
#   226,
#   105,
#   7,
#   68,
#   625,
#   34,
#   14],
#  [40276, 1, 81, 9, 139, 37, 884, 266, 6460, 3795, 303, 191],
#  [40277, 684, 7, 1729, 9],
#  [3364,
#   571,
#   4590,
#   13,
#   3,
#   7483,
#   8,
#   245,
#   739,
#   29,
#   949,
#   79,
#   1,
#   77,
#   9,
#   1532,
#   32,
#   3,
#   666,
#   3424,
#   18910,
#   1495,
#   25,
#   253,
#   33,
#   28,
#   26],
#  [1, 64, 416, 6, 17, 85, 42, 311, 28, 280, 84, 5, 692, 8, 15, 114],
#  [24865,
#   153,
#   370,
#   2,
#   6487,
#   419,
#   75,
#   700,
#   23,
#   40278,
#   3642,
#   1,
#   68,
#   113,
#   446,
#   10,
#   95,
#   394,
#   6,
#   4,
#   132,
#   24865],
#  [1133,
#   248,
#   1,
#   25,
#   128,
#   4,
#   28,
#   1110,
#   13,
#   4,
#   2727,
#   2167,
#   18,
#   1,
#   147,
#   606,
#   411,
#   1771,
#   2,
#   3,
#   1573,
#   42,
#   274,
#   7072,
#   45,
#   250],
#  [18911, 1, 5331, 2, 131, 2, 15703, 6, 390, 3, 254],
#  [720, 5983, 3003, 618, 45, 264, 2, 115],
#  [40279, 42, 218, 12, 3, 5545, 143, 3957, 29, 11, 341, 210, 470, 12, 283],
#  [458, 308],
#  [8, 4, 260, 21, 311, 4, 40280, 1383, 143, 22, 11, 40281, 126, 40282],
#  [40283,
#   1977,
#   116,
#   290,
#   110,
#   16,
#   2,
#   46,
#   109,
#   1,
#   69,
#   233,
#   19,
#   24,
#   1930,
#   305,
#   305],
#  [40284, 1, 77, 359, 52, 1, 151, 8816, 9, 192, 618, 43, 8, 20, 314, 3, 2800],
#  [40285, 5, 7073, 180, 36],
#  [1,
#   108,
#   34,
#   235,
#   8,
#   1042,
#   6,
#   2429,
#   234,
#   13568,
#   19,
#   135,
#   90,
#   5,
#   15704,
#   15,
#   15,
#   91],
#  [24866, 8, 41, 78, 916, 29],
#  [328, 4602, 3053, 9, 141, 475, 191, 65, 89, 2, 140],
#  [24867, 53, 380],
#  [1,
#   46,
#   5,
#   269,
#   563,
#   40286,
#   2482,
#   13,
#   4,
#   260,
#   185,
#   48,
#   13569,
#   143,
#   370,
#   6,
#   25,
#   469,
#   230,
#   6,
#   143,
#   25,
#   382,
#   2,
#   14],
#  [40287,
#   185,
#   35,
#   3,
#   2301,
#   172,
#   167,
#   22,
#   14,
#   1,
#   167,
#   81,
#   9,
#   8,
#   18,
#   1,
#   145,
#   22,
#   428,
#   1,
#   16,
#   102,
#   4,
#   887,
#   12,
#   372],
#  [1259, 2515, 6, 770, 3570, 5, 10136, 3718, 310, 37, 2, 6768, 244, 2302],
#  [100,
#   24868,
#   455,
#   23,
#   186,
#   1109,
#   103,
#   23,
#   571,
#   6,
#   594,
#   2,
#   1149,
#   89,
#   3,
#   146,
#   21,
#   1173,
#   13,
#   339,
#   23,
#   571,
#   216],
#  [580, 114, 372],
#  [18912, 40288, 66, 130, 820, 161, 222, 3, 18913, 25, 4603],
#  [40289, 808, 3, 1196, 13570],
#  [935, 1, 25, 11, 1554, 45, 67, 5, 18914, 363],
#  [6, 1, 16, 3, 173, 901, 232, 166, 82, 323, 6, 488],
#  [5546, 5, 825, 52, 2, 2607],
#  [47,
#   52,
#   80,
#   40,
#   160,
#   104,
#   159,
#   11,
#   3,
#   1523,
#   228,
#   94,
#   2,
#   31,
#   52,
#   2,
#   5,
#   316,
#   253,
#   9],
#  [1174,
#   5,
#   346,
#   11,
#   2,
#   22,
#   1115,
#   9420,
#   4232,
#   967,
#   52,
#   2,
#   549,
#   5,
#   243,
#   15705,
#   10,
#   3,
#   162,
#   364,
#   764,
#   159],
#  [4356,
#   39,
#   398,
#   56,
#   40290,
#   8328,
#   24869,
#   52,
#   11,
#   4861,
#   11,
#   193,
#   109,
#   40291,
#   39,
#   442,
#   56,
#   231,
#   40292],
#  [421, 559],
#  [40293,
#   8,
#   194,
#   138,
#   21,
#   3,
#   2199,
#   261,
#   41,
#   1073,
#   6,
#   2834,
#   2059,
#   17,
#   110,
#   594,
#   161,
#   138,
#   103],
#  [40294,
#   1,
#   209,
#   66,
#   1314,
#   6,
#   4604,
#   21,
#   5005,
#   7,
#   145,
#   293,
#   750,
#   3313,
#   4605,
#   12,
#   605,
#   11,
#   3,
#   40295,
#   10,
#   2105,
#   294],
#  [100, 4606, 133, 160, 188, 347, 10, 34, 232, 3248, 99, 1036, 540],
#  [40296,
#   227,
#   1,
#   57,
#   391,
#   186,
#   3643,
#   65,
#   44,
#   40297,
#   12,
#   9,
#   1137,
#   2918,
#   21,
#   74,
#   1030,
#   3571,
#   1996,
#   18915,
#   65,
#   4458,
#   40298,
#   5154,
#   373],
#  [8834, 35, 4862, 2, 22, 683, 2, 3, 515, 15, 812, 9],
#  [40299, 36, 119, 2683],
#  [1455,
#   15,
#   1228,
#   11,
#   5,
#   669,
#   61,
#   211,
#   20,
#   1277,
#   6,
#   2303,
#   21,
#   4,
#   664,
#   68,
#   127,
#   17,
#   719,
#   10,
#   383,
#   553,
#   2520],
#  [40300, 325, 266, 58, 108, 266, 183, 209, 51, 824, 797, 295],
#  [15, 1197, 179, 51, 92, 73, 1, 117, 5, 333, 121, 20, 37, 229, 8820],
#  [20,
#   48,
#   204,
#   3,
#   379,
#   234,
#   24870,
#   23,
#   10137,
#   6,
#   88,
#   7905,
#   14,
#   89,
#   10,
#   87,
#   15706,
#   11,
#   3,
#   631,
#   12,
#   5332],
#  [40301, 58, 93, 7074, 43, 3495],
#  [40302, 24, 215, 366, 2, 40303, 2789],
#  [2954, 2, 24871, 7075, 147, 16, 2, 908, 422, 3719, 203, 14, 532],
#  [40304,
#   55,
#   63,
#   150,
#   5,
#   13571,
#   3958,
#   24872,
#   434,
#   1497,
#   5984,
#   24873,
#   5165,
#   411,
#   7076],
#  [97, 8329, 3, 4607, 10997, 8, 29, 13, 321, 40305, 56, 37, 340, 9, 32],
#  [1, 208, 9, 1969, 17, 1, 16, 1456, 12, 43, 13, 3100, 18, 355, 1257, 13, 1838],
#  [172,
#   287,
#   14,
#   79,
#   2,
#   31,
#   4,
#   780,
#   3141,
#   12089,
#   10998,
#   32,
#   12,
#   833,
#   1524,
#   2168,
#   172],
#  [40306,
#   4608,
#   1,
#   18916,
#   4357,
#   7,
#   51,
#   41,
#   99,
#   462,
#   105,
#   2456,
#   1,
#   20,
#   282,
#   2,
#   22,
#   2553,
#   185,
#   3572,
#   5,
#   798,
#   337,
#   15707,
#   4,
#   1533],
#  [1, 16, 876, 262, 2, 44, 43, 1648, 1027, 103, 6, 1, 62, 182, 37, 24874],
#  [170,
#   248,
#   1,
#   121,
#   44,
#   17,
#   581,
#   4,
#   7484,
#   13572,
#   160,
#   1,
#   40307,
#   205,
#   7484,
#   10,
#   54,
#   146,
#   51,
#   4,
#   268,
#   612,
#   40308,
#   4,
#   315],
#  [24875, 18917],
#  [348,
#   207,
#   1,
#   16,
#   18918,
#   6,
#   2224,
#   6488,
#   5547,
#   2018,
#   17,
#   1,
#   64,
#   23,
#   80,
#   6,
#   194,
#   76,
#   1,
#   247,
#   5,
#   322,
#   70,
#   7077,
#   274,
#   473,
#   12,
#   606,
#   347],
#  [40309, 137, 42, 60, 1260, 10, 9, 386, 9],
#  [4463, 10138, 35, 52],
#  [2400, 29, 23, 2580, 305, 2608, 160, 92, 657, 24, 120],
#  [40310, 70, 54, 12, 5, 649, 364, 108, 28, 655],
#  [144,
#   55,
#   1,
#   376,
#   5985,
#   1465,
#   177,
#   3959,
#   2,
#   4,
#   600,
#   61,
#   139,
#   33,
#   241,
#   3,
#   3959,
#   2,
#   2554],
#  [8,
#   181,
#   4,
#   129,
#   6,
#   3879,
#   157,
#   7485,
#   249,
#   2,
#   71,
#   12,
#   5,
#   363,
#   349,
#   5,
#   950,
#   69,
#   142,
#   2,
#   31,
#   158,
#   359],
#  [3004, 40311, 153, 82, 10, 438, 14, 1, 59, 992, 12, 41, 3142],
#  [122, 115, 171, 5, 508, 8, 24876, 21, 15, 327, 251, 3880, 40312],
#  [406, 78, 5006, 15, 120, 2, 16, 7, 1043, 10, 3, 771],
#  [5, 945, 24, 120],
#  [92, 30, 23, 80, 784, 2, 3, 1614, 10, 3, 235, 103],
#  [205,
#   174,
#   593,
#   43,
#   30,
#   6,
#   1,
#   16,
#   2,
#   22,
#   29,
#   23,
#   239,
#   2,
#   7,
#   8330,
#   9,
#   43,
#   15,
#   36,
#   1171,
#   10,
#   14,
#   103],
#  [3249, 622, 16, 4, 1420, 593, 184],
#  [7906, 1209, 1789, 884, 166, 172],
#  [31, 2, 67, 3138, 6, 40313, 277, 804, 4233, 142],
#  [3, 3425, 35, 912, 6, 237, 2, 2919, 14, 258, 2143, 130, 352],
#  [1, 94, 71, 1107, 10139, 1013, 197, 4, 1446],
#  [18919,
#   79,
#   44,
#   7,
#   207,
#   1807,
#   13573,
#   1,
#   77,
#   2,
#   3644,
#   130,
#   799,
#   691,
#   36,
#   10140,
#   392,
#   535,
#   24877,
#   39,
#   8,
#   1047,
#   40314,
#   3426],
#  [40315, 82, 10, 438, 14, 6, 1, 1869, 5, 798, 2728, 10, 7],
#  [60,
#   580,
#   26,
#   117,
#   1,
#   66,
#   20,
#   354,
#   3,
#   1514,
#   13,
#   3,
#   9421,
#   6,
#   24,
#   11,
#   4,
#   848,
#   8331,
#   530,
#   22,
#   224,
#   10,
#   205,
#   74,
#   221],
#  [69, 127, 9, 2, 43, 426, 5157, 24878],
#  [24879,
#   12,
#   539,
#   19,
#   4716,
#   15,
#   227,
#   5,
#   3198,
#   555,
#   130,
#   24880,
#   1,
#   69,
#   7907,
#   130,
#   232,
#   482,
#   63,
#   130,
#   358],
#  [636, 1905, 6769, 18920, 163, 304, 10, 441, 133, 1638, 3496],
#  [1995,
#   166,
#   1,
#   64,
#   461,
#   3250,
#   63,
#   78,
#   849,
#   168,
#   1204,
#   47,
#   2,
#   3,
#   6483,
#   48,
#   9,
#   518],
#  [246, 46, 3, 279, 40316, 294, 9, 66, 98, 112],
#  [24881],
#  [19,
#   441,
#   5986,
#   2,
#   31,
#   193,
#   571,
#   561,
#   1744,
#   5,
#   341,
#   288,
#   8,
#   209,
#   11,
#   548,
#   51,
#   193,
#   1226,
#   104,
#   270,
#   11,
#   26,
#   1744,
#   1783],
#  [40317, 302, 15708, 79, 35, 7, 194, 129, 2, 496, 53, 107],
#  [40318, 8, 11, 2609, 450, 1790, 15709, 8, 24, 724],
#  [116, 290, 5, 515, 541],
#  [646, 36, 831, 10, 14, 39, 442, 56, 231, 40319],
#  [1, 90, 40320, 1, 117, 110, 9422, 447],
#  [1, 77, 205, 40321],
#  [40322, 106, 144, 3, 184, 61, 370, 2, 37, 2, 18, 61, 16, 152],
#  [7908, 19, 4, 99, 3573, 4234, 12090, 401, 4, 2920, 93, 1, 131],
#  [9, 8, 289, 2, 16, 36, 7486],
#  [15710, 185, 1061, 18, 7, 68, 1082, 2, 14],
#  [76, 1, 245, 48, 2, 115],
#  [4135,
#   1852,
#   2457,
#   451,
#   1,
#   59,
#   211,
#   41,
#   47,
#   6,
#   72,
#   42,
#   211,
#   1,
#   81,
#   9,
#   8,
#   240,
#   14,
#   59,
#   72,
#   5,
#   8835,
#   8,
#   75,
#   13,
#   3,
#   450],
#  [40323,
#   37,
#   11,
#   103,
#   240,
#   14,
#   59,
#   55,
#   88,
#   180,
#   287,
#   130,
#   7,
#   16,
#   4609,
#   6,
#   13574,
#   2,
#   40324,
#   130,
#   13,
#   436,
#   65,
#   939],
#  [18921,
#   19,
#   2169,
#   17,
#   1,
#   253,
#   9,
#   18,
#   1,
#   59,
#   53,
#   125,
#   41,
#   210,
#   1014,
#   199,
#   18922,
#   13575],
#  [1,
#   707,
#   9,
#   25,
#   4,
#   28,
#   324,
#   2,
#   318,
#   80,
#   244,
#   679,
#   687,
#   280,
#   39,
#   442,
#   56,
#   231,
#   40325],
#  [40326, 97, 2515, 340, 41, 4136, 172],
#  [40327, 36, 633, 1, 10120, 3, 267, 30, 45, 1, 5987, 7, 194, 55, 150, 194],
#  [28, 97, 187, 42, 1309, 30],
#  [40328,
#   18923,
#   154,
#   48,
#   4,
#   315,
#   12,
#   109,
#   921,
#   18,
#   24,
#   807,
#   44,
#   53,
#   34,
#   109,
#   316],
#  [24882, 19, 24, 89, 360, 10141],
#  [5333, 5166, 1038],
#  [381,
#   2,
#   655,
#   63,
#   824,
#   24883,
#   3365,
#   1354,
#   6,
#   5334,
#   1822,
#   1,
#   46,
#   14,
#   71,
#   1212,
#   316,
#   11,
#   3,
#   5007],
#  [40329, 144, 55, 1, 220, 21],
#  [40330, 1750, 150, 234, 163, 7],
#  [28, 97],
#  [24884,
#   1,
#   59,
#   1,
#   16,
#   253,
#   7,
#   293,
#   1,
#   16,
#   20,
#   102,
#   237,
#   2,
#   31,
#   92,
#   152,
#   294,
#   204,
#   9,
#   57,
#   22,
#   33,
#   133,
#   13,
#   339],
#  [40331, 725, 20, 800, 5, 444, 50, 15711, 2, 249, 147, 31, 91, 3574],
#  [40332,
#   1,
#   415,
#   727,
#   21,
#   206,
#   254,
#   447,
#   333,
#   10142,
#   9,
#   25,
#   6489,
#   1672,
#   23,
#   4358,
#   123,
#   5335,
#   9,
#   25,
#   8332,
#   21,
#   254,
#   415,
#   1982],
#  [7487, 137, 1, 151, 285, 3, 379, 45],
#  [7488, 845, 33, 1, 60, 62, 77, 2, 37, 2, 43, 877],
#  [1, 20, 247, 5761, 13576, 11, 1310, 7909, 11, 3, 303],
#  [40333, 15, 19, 194, 71, 2028, 6, 175, 13, 5, 1666, 10, 3, 157, 6, 162, 146],
#  [40334,
#   4,
#   780,
#   214,
#   279,
#   1311,
#   378,
#   522,
#   12,
#   9423,
#   46,
#   7,
#   45,
#   1407,
#   40,
#   498,
#   4,
#   28,
#   30],
#  ...]

# %%
tokenizer.word_index
# Out:
# {'i': 1,
#  'to': 2,
#  'the': 3,
#  'a': 4,
#  'my': 5,
#  'and': 6,
#  'you': 7,
#  'is': 8,
#  'it': 9,
#  'for': 10,
#  'in': 11,
#  'of': 12,
#  'on': 13,
#  'me': 14,
#  'so': 15,
#  'have': 16,
#  'that': 17,
#  'but': 18,
#  "i'm": 19,
#  'just': 20,
#  'with': 21,
#  'be': 22,
#  'at': 23,
#  'not': 24,
#  'was': 25,
#  'now': 26,
#  'this': 27,
#  'good': 28,
#  'up': 29,
#  'day': 30,
#  'get': 31,
#  'out': 32,
#  'all': 33,
#  'like': 34,
#  'are': 35,
#  'no': 36,
#  'go': 37,
#  'quot': 38,
#  'http': 39,
#  'today': 40,
#  'your': 41,
#  "it's": 42,
#  'work': 43,
#  'do': 44,
#  'too': 45,
#  'love': 46,
#  'going': 47,
#  'got': 48,
#  'lol': 49,
#  'time': 50,
#  'from': 51,
#  'back': 52,
#  'u': 53,
#  'one': 54,
#  'what': 55,
#  'com': 56,
#  'will': 57,
#  'im': 58,
#  'know': 59,
#  'really': 60,
#  'we': 61,
#  "don't": 62,
#  'about': 63,
#  'am': 64,
#  'amp': 65,
#  'had': 66,
#  'see': 67,
#  'can': 68,
#  "can't": 69,
#  'its': 70,
#  'some': 71,
#  'if': 72,
#  'night': 73,
#  '2': 74,
#  'still': 75,
#  'well': 76,
#  'want': 77,
#  'new': 78,
#  'how': 79,
#  'home': 80,
#  'think': 81,
#  'thanks': 82,
#  'there': 83,
#  'oh': 84,
#  'when': 85,
#  'as': 86,
#  'more': 87,
#  'they': 88,
#  'off': 89,
#  'miss': 90,
#  'much': 91,
#  'last': 92,
#  'here': 93,
#  'need': 94,
#  'an': 95,
#  'then': 96,
#  'morning': 97,
#  'great': 98,
#  'twitter': 99,
#  'has': 100,
#  'hope': 101,
#  'been': 102,
#  'tomorrow': 103,
#  '3': 104,
#  'or': 105,
#  'haha': 106,
#  'again': 107,
#  'feel': 108,
#  'her': 109,
#  'he': 110,
#  'sad': 111,
#  'fun': 112,
#  'only': 113,
#  'bad': 114,
#  'sleep': 115,
#  'why': 116,
#  'wish': 117,
#  'right': 118,
#  'very': 119,
#  'happy': 120,
#  'would': 121,
#  "i'll": 122,
#  'by': 123,
#  'sorry': 124,
#  'did': 125,
#  'tonight': 126,
#  'make': 127,
#  'getting': 128,
#  'nice': 129,
#  'them': 130,
#  'come': 131,
#  'bit': 132,
#  'over': 133,
#  'though': 134,
#  'gonna': 135,
#  'way': 136,
#  'yeah': 137,
#  'better': 138,
#  'should': 139,
#  'bed': 140,
#  'watching': 141,
#  'wait': 142,
#  'she': 143,
#  "that's": 144,
#  'could': 145,
#  'week': 146,
#  "didn't": 147,
#  'people': 148,
#  'twitpic': 149,
#  "you're": 150,
#  'hate': 151,
#  'school': 152,
#  'hey': 153,
#  "i've": 154,
#  'lt': 155,
#  '4': 156,
#  'weekend': 157,
#  'him': 158,
#  'days': 159,
#  'after': 160,
#  'even': 161,
#  'next': 162,
#  'thank': 163,
#  'down': 164,
#  'awesome': 165,
#  'yes': 166,
#  'dont': 167,
#  'were': 168,
#  'cant': 169,
#  'never': 170,
#  'soon': 171,
#  'please': 172,
#  'best': 173,
#  'long': 174,
#  'working': 175,
#  'take': 176,
#  'little': 177,
#  'first': 178,
#  'tired': 179,
#  'say': 180,
#  'having': 181,
#  'wanna': 182,
#  'sick': 183,
#  'show': 184,
#  'who': 185,
#  '1': 186,
#  'everyone': 187,
#  'being': 188,
#  'x': 189,
#  'watch': 190,
#  'life': 191,
#  'always': 192,
#  'his': 193,
#  'doing': 194,
#  'sure': 195,
#  'us': 196,
#  'feeling': 197,
#  'ok': 198,
#  'any': 199,
#  'cool': 200,
#  'friends': 201,
#  'something': 202,
#  'made': 203,
#  'done': 204,
#  'another': 205,
#  'our': 206,
#  'guys': 207,
#  'find': 208,
#  'already': 209,
#  'thing': 210,
#  'where': 211,
#  'look': 212,
#  'than': 213,
#  'man': 214,
#  'looking': 215,
#  'yay': 216,
#  'ly': 217,
#  'because': 218,
#  'phone': 219,
#  'went': 220,
#  'hours': 221,
#  'before': 222,
#  'ur': 223,
#  'ready': 224,
#  'yet': 225,
#  'tweet': 226,
#  'maybe': 227,
#  'house': 228,
#  'away': 229,
#  'pretty': 230,
#  'p': 231,
#  'ever': 232,
#  'help': 233,
#  'amazing': 234,
#  'summer': 235,
#  'omg': 236,
#  'trying': 237,
#  'movie': 238,
#  '5': 239,
#  'let': 240,
#  'follow': 241,
#  'damn': 242,
#  'old': 243,
#  'early': 244,
#  'finally': 245,
#  'wow': 246,
#  'lost': 247,
#  'thought': 248,
#  'someone': 249,
#  'big': 250,
#  'things': 251,
#  'left': 252,
#  'missed': 253,
#  'rain': 254,
#  'bored': 255,
#  'year': 256,
#  'guess': 257,
#  'into': 258,
#  'same': 259,
#  'girl': 260,
#  'keep': 261,
#  'nothing': 262,
#  'looks': 263,
#  'hot': 264,
#  'glad': 265,
#  'n': 266,
#  'other': 267,
#  'friend': 268,
#  'song': 269,
#  'coming': 270,
#  'while': 271,
#  'birthday': 272,
#  'w': 273,
#  'two': 274,
#  'sucks': 275,
#  'makes': 276,
#  'later': 277,
#  'start': 278,
#  'sun': 279,
#  'weather': 280,
#  "won't": 281,
#  'try': 282,
#  'ya': 283,
#  'thats': 284,
#  'those': 285,
#  'live': 286,
#  'tell': 287,
#  'baby': 288,
#  'hard': 289,
#  'does': 290,
#  "doesn't": 291,
#  'saw': 292,
#  'also': 293,
#  'stuff': 294,
#  'ugh': 295,
#  'excited': 296,
#  'hear': 297,
#  'party': 298,
#  'yesterday': 299,
#  'play': 300,
#  'actually': 301,
#  'hi': 302,
#  'game': 303,
#  'god': 304,
#  'o': 305,
#  'since': 306,
#  'until': 307,
#  'world': 308,
#  'few': 309,
#  'gotta': 310,
#  'such': 311,
#  'waiting': 312,
#  'said': 313,
#  'around': 314,
#  'lot': 315,
#  'music': 316,
#  'might': 317,
#  'head': 318,
#  'myself': 319,
#  'job': 320,
#  'www': 321,
#  'car': 322,
#  'mom': 323,
#  'call': 324,
#  'b': 325,
#  'late': 326,
#  'many': 327,
#  'beautiful': 328,
#  'luck': 329,
#  'found': 330,
#  'their': 331,
#  'must': 332,
#  'cold': 333,
#  'aww': 334,
#  'talk': 335,
#  'read': 336,
#  'give': 337,
#  'sounds': 338,
#  'friday': 339,
#  'check': 340,
#  'poor': 341,
#  'cute': 342,
#  'stop': 343,
#  'sunday': 344,
#  'may': 345,
#  'iphone': 346,
#  'gone': 347,
#  'okay': 348,
#  'missing': 349,
#  "haven't": 350,
#  'r': 351,
#  'free': 352,
#  "he's": 353,
#  'put': 354,
#  'almost': 355,
#  'anything': 356,
#  'making': 357,
#  'tho': 358,
#  'monday': 359,
#  'till': 360,
#  'far': 361,
#  'hurts': 362,
#  'family': 363,
#  '10': 364,
#  'woke': 365,
#  'forward': 366,
#  'eat': 367,
#  'playing': 368,
#  'least': 369,
#  'wanted': 370,
#  'gt': 371,
#  'times': 372,
#  'lunch': 373,
#  "i'd": 374,
#  'food': 375,
#  'believe': 376,
#  'leave': 377,
#  'use': 378,
#  'most': 379,
#  'funny': 380,
#  'listening': 381,
#  'mean': 382,
#  'real': 383,
#  'shit': 384,
#  'which': 385,
#  "isn't": 386,
#  'hair': 387,
#  'finished': 388,
#  'dinner': 389,
#  'enjoy': 390,
#  'buy': 391,
#  'anyone': 392,
#  'followers': 393,
#  'hour': 394,
#  'hahaha': 395,
#  'end': 396,
#  'video': 397,
#  'tinyurl': 398,
#  'd': 399,
#  'thinking': 400,
#  't': 401,
#  'sweet': 402,
#  'everything': 403,
#  'these': 404,
#  'ha': 405,
#  'welcome': 406,
#  'coffee': 407,
#  'didnt': 408,
#  'outside': 409,
#  'mine': 410,
#  'enough': 411,
#  'through': 412,
#  '6': 413,
#  'anymore': 414,
#  'totally': 415,
#  'ill': 416,
#  's': 417,
#  'every': 418,
#  "we're": 419,
#  'win': 420,
#  'eating': 421,
#  'stupid': 422,
#  'place': 423,
#  'busy': 424,
#  'without': 425,
#  'probably': 426,
#  'cause': 427,
#  'wrong': 428,
#  'wants': 429,
#  'weeks': 430,
#  'once': 431,
#  'money': 432,
#  'xx': 433,
#  'lovely': 434,
#  'kinda': 435,
#  'tv': 436,
#  'tweets': 437,
#  'following': 438,
#  'class': 439,
#  'pic': 440,
#  'taking': 441,
#  'plurk': 442,
#  'room': 443,
#  'whole': 444,
#  "there's": 445,
#  'stay': 446,
#  'came': 447,
#  '30': 448,
#  'saturday': 449,
#  'beach': 450,
#  'says': 451,
#  'sooo': 452,
#  'headache': 453,
#  '8': 454,
#  'exam': 455,
#  "she's": 456,
#  "what's": 457,
#  'hello': 458,
#  'reading': 459,
#  'news': 460,
#  'super': 461,
#  'name': 462,
#  'book': 463,
#  'hopefully': 464,
#  'forgot': 465,
#  '7': 466,
#  'computer': 467,
#  'seen': 468,
#  'hell': 469,
#  'both': 470,
#  'awww': 471,
#  'took': 472,
#  'years': 473,
#  'crazy': 474,
#  'true': 475,
#  'kids': 476,
#  'shopping': 477,
#  'half': 478,
#  'rest': 479,
#  'able': 480,
#  'soo': 481,
#  'talking': 482,
#  'face': 483,
#  'post': 484,
#  'feels': 485,
#  'c': 486,
#  'guy': 487,
#  'dad': 488,
#  'boo': 489,
#  'idea': 490,
#  'cuz': 491,
#  'full': 492,
#  'alone': 493,
#  'girls': 494,
#  'goodnight': 495,
#  'meet': 496,
#  'blog': 497,
#  "wasn't": 498,
#  'send': 499,
#  'own': 500,
#  'either': 501,
#  'needs': 502,
#  'office': 503,
#  'ago': 504,
#  'ah': 505,
#  'trip': 506,
#  'quite': 507,
#  'mind': 508,
#  'seems': 509,
#  "they're": 510,
#  'used': 511,
#  'sitting': 512,
#  'dog': 513,
#  'leaving': 514,
#  'heart': 515,
#  "couldn't": 516,
#  'watched': 517,
#  'hehe': 518,
#  'fuck': 519,
#  'kind': 520,
#  'hit': 521,
#  'lots': 522,
#  'online': 523,
#  'm': 524,
#  'raining': 525,
#  'remember': 526,
#  'run': 527,
#  'stuck': 528,
#  'part': 529,
#  'wont': 530,
#  'started': 531,
#  'cry': 532,
#  'else': 533,
#  'boy': 534,
#  'tried': 535,
#  'btw': 536,
#  'broke': 537,
#  'break': 538,
#  'course': 539,
#  'facebook': 540,
#  'hurt': 541,
#  'heard': 542,
#  'internet': 543,
#  'seeing': 544,
#  'pics': 545,
#  'anyway': 546,
#  'fine': 547,
#  'pain': 548,
#  'using': 549,
#  'goes': 550,
#  'seriously': 551,
#  'add': 552,
#  'june': 553,
#  'sunny': 554,
#  'called': 555,
#  'boring': 556,
#  'minutes': 557,
#  'awake': 558,
#  'breakfast': 559,
#  'aw': 560,
#  'month': 561,
#  'la': 562,
#  'picture': 563,
#  'mileycyrus': 564,
#  'loved': 565,
#  'update': 566,
#  'reply': 567,
#  'asleep': 568,
#  'soooo': 569,
#  'walk': 570,
#  '9': 571,
#  'told': 572,
#  'tommcfly': 573,
#  'change': 574,
#  'lmao': 575,
#  'rock': 576,
#  'fan': 577,
#  'xd': 578,
#  'crap': 579,
#  'hungry': 580,
#  'bought': 581,
#  'care': 582,
#  'train': 583,
#  'died': 584,
#  'starting': 585,
#  'bye': 586,
#  'jealous': 587,
#  'wake': 588,
#  'concert': 589,
#  'youtube': 590,
#  'drive': 591,
#  'season': 592,
#  'ass': 593,
#  'gets': 594,
#  'red': 595,
#  'lucky': 596,
#  'exams': 597,
#  'mad': 598,
#  'fucking': 599,
#  'person': 600,
#  'instead': 601,
#  'til': 602,
#  'e': 603,
#  'link': 604,
#  'text': 605,
#  'pay': 606,
#  'yea': 607,
#  '100': 608,
#  'open': 609,
#  'dude': 610,
#  'favorite': 611,
#  'enjoying': 612,
#  'bring': 613,
#  'write': 614,
#  "you'll": 615,
#  'dear': 616,
#  'wonderful': 617,
#  'means': 618,
#  'shower': 619,
#  'heading': 620,
#  'ice': 621,
#  'afternoon': 622,
#  'together': 623,
#  'site': 624,
#  'study': 625,
#  '0': 626,
#  'ask': 627,
#  'weird': 628,
#  'high': 629,
#  'hoping': 630,
#  'city': 631,
#  'homework': 632,
#  'problem': 633,
#  '12': 634,
#  'sleeping': 635,
#  'loves': 636,
#  'laptop': 637,
#  'water': 638,
#  'ppl': 639,
#  'town': 640,
#  'move': 641,
#  'ipod': 642,
#  "we'll": 643,
#  're': 644,
#  'happened': 645,
#  'definitely': 646,
#  'fail': 647,
#  'tour': 648,
#  'top': 649,
#  'sigh': 650,
#  'reason': 651,
#  'sore': 652,
#  'cut': 653,
#  'sister': 654,
#  'songs': 655,
#  'comes': 656,
#  'nite': 657,
#  'gym': 658,
#  'album': 659,
#  'dead': 660,
#  'couple': 661,
#  'visit': 662,
#  'fm': 663,
#  'drink': 664,
#  'won': 665,
#  'final': 666,
#  "let's": 667,
#  '20': 668,
#  'dream': 669,
#  'suck': 670,
#  'goin': 671,
#  'eyes': 672,
#  'running': 673,
#  'works': 674,
#  'finish': 675,
#  'tea': 676,
#  'church': 677,
#  'seem': 678,
#  'perfect': 679,
#  'sometimes': 680,
#  'brother': 681,
#  'ive': 682,
#  'close': 683,
#  'congrats': 684,
#  'studying': 685,
#  'worst': 686,
#  'nap': 687,
#  'bout': 688,
#  'pool': 689,
#  'boys': 690,
#  'email': 691,
#  'english': 692,
#  'dance': 693,
#  'movies': 694,
#  'listen': 695,
#  'gave': 696,
#  'ate': 697,
#  'short': 698,
#  'k': 699,
#  'meeting': 700,
#  'months': 701,
#  'chocolate': 702,
#  'evening': 703,
#  'ddlovato': 704,
#  'less': 705,
#  'saying': 706,
#  'knew': 707,
#  'hmm': 708,
#  'interesting': 709,
#  'cat': 710,
#  'y': 711,
#  'clean': 712,
#  'team': 713,
#  'blip': 714,
#  'loving': 715,
#  'cream': 716,
#  '11': 717,
#  "wouldn't": 718,
#  'happen': 719,
#  'air': 720,
#  'photo': 721,
#  'list': 722,
#  'side': 723,
#  'unfortunately': 724,
#  'yep': 725,
#  'sound': 726,
#  'agree': 727,
#  'writing': 728,
#  'hang': 729,
#  'star': 730,
#  'l': 731,
#  'wedding': 732,
#  'wishing': 733,
#  'test': 734,
#  'throat': 735,
#  'supposed': 736,
#  'turn': 737,
#  '1st': 738,
#  'set': 739,
#  'worth': 740,
#  'word': 741,
#  'ones': 742,
#  'second': 743,
#  "'": 744,
#  'xxx': 745,
#  'past': 746,
#  'tickets': 747,
#  'pictures': 748,
#  'mr': 749,
#  'store': 750,
#  'page': 751,
#  'fb': 752,
#  'ahh': 753,
#  'followfriday': 754,
#  'park': 755,
#  'smile': 756,
#  'myspace': 757,
#  'mood': 758,
#  'moment': 759,
#  'forget': 760,
#  'broken': 761,
#  'fast': 762,
#  'uk': 763,
#  '15': 764,
#  'lil': 765,
#  'under': 766,
#  'catch': 767,
#  'fall': 768,
#  'upset': 769,
#  'sleepy': 770,
#  'ride': 771,
#  'awards': 772,
#  'scared': 773,
#  'sunshine': 774,
#  'easy': 775,
#  'date': 776,
#  'sat': 777,
#  'account': 778,
#  'bet': 779,
#  'black': 780,
#  'lady': 781,
#  'horrible': 782,
#  'mac': 783,
#  'moving': 784,
#  'sent': 785,
#  'bday': 786,
#  'jonas': 787,
#  'flu': 788,
#  'hugs': 789,
#  'plan': 790,
#  'chance': 791,
#  'driving': 792,
#  'understand': 793,
#  "aren't": 794,
#  'london': 795,
#  'jonasbrothers': 796,
#  'earlier': 797,
#  'updates': 798,
#  'via': 799,
#  'spent': 800,
#  'worse': 801,
#  'dreams': 802,
#  'story': 803,
#  'cannot': 804,
#  'shame': 805,
#  'tweeting': 806,
#  'miley': 807,
#  'whats': 808,
#  'cake': 809,
#  'thx': 810,
#  'green': 811,
#  'wear': 812,
#  "you've": 813,
#  'hanging': 814,
#  'wtf': 815,
#  'tuesday': 816,
#  'college': 817,
#  'due': 818,
#  'three': 819,
#  'longer': 820,
#  'plus': 821,
#  'words': 822,
#  'mum': 823,
#  'drinking': 824,
#  'flight': 825,
#  'camera': 826,
#  'wonder': 827,
#  'hand': 828,
#  'google': 829,
#  'support': 830,
#  'vacation': 831,
#  'apparently': 832,
#  'white': 833,
#  'body': 834,
#  'answer': 835,
#  'ahhh': 836,
#  'idk': 837,
#  'special': 838,
#  'thinks': 839,
#  'plans': 840,
#  'photos': 841,
#  'point': 842,
#  'pick': 843,
#  'lazy': 844,
#  'da': 845,
#  'doesnt': 846,
#  'fell': 847,
#  'slow': 848,
#  'moon': 849,
#  'vote': 850,
#  'met': 851,
#  'holiday': 852,
#  'wondering': 853,
#  'lonely': 854,
#  'rather': 855,
#  'shows': 856,
#  'band': 857,
#  'voice': 858,
#  'cleaning': 859,
#  'mtv': 860,
#  'spend': 861,
#  'join': 862,
#  'officially': 863,
#  'worry': 864,
#  'stomach': 865,
#  'forever': 866,
#  'beer': 867,
#  'kill': 868,
#  'inside': 869,
#  'huge': 870,
#  'felt': 871,
#  'message': 872,
#  'fair': 873,
#  'figure': 874,
#  'especially': 875,
#  'absolutely': 876,
#  '2day': 877,
#  'dress': 878,
#  'fix': 879,
#  'luv': 880,
#  'line': 881,
#  'pizza': 882,
#  'nope': 883,
#  'chicken': 884,
#  'tom': 885,
#  'july': 886,
#  'number': 887,
#  'slept': 888,
#  'havent': 889,
#  'project': 890,
#  'during': 891,
#  'blue': 892,
#  'yourself': 893,
#  'warm': 894,
#  'sims': 895,
#  'bbq': 896,
#  'sadly': 897,
#  'david': 898,
#  'liked': 899,
#  'small': 900,
#  'parents': 901,
#  'chat': 902,
#  'laugh': 903,
#  'rainy': 904,
#  'annoying': 905,
#  'learn': 906,
#  'wine': 907,
#  'die': 908,
#  'bus': 909,
#  'save': 910,
#  'hmmm': 911,
#  'crying': 912,
#  'airport': 913,
#  'boyfriend': 914,
#  'shall': 915,
#  'website': 916,
#  'keeps': 917,
#  'yummy': 918,
#  'gorgeous': 919,
#  'shoes': 920,
#  'fans': 921,
#  'shirt': 922,
#  'different': 923,
#  'bike': 924,
#  'thursday': 925,
#  'power': 926,
#  'games': 927,
#  'alright': 928,
#  'french': 929,
#  'looked': 930,
#  'graduation': 931,
#  'lets': 932,
#  'hubby': 933,
#  'brothers': 934,
#  'wishes': 935,
#  'ff': 936,
#  'exciting': 937,
#  'eye': 938,
#  'radio': 939,
#  'apple': 940,
#  'near': 941,
#  'v': 942,
#  'meant': 943,
#  'beat': 944,
#  'tummy': 945,
#  'hug': 946,
#  'decided': 947,
#  'xoxo': 948,
#  'exactly': 949,
#  'son': 950,
#  'shop': 951,
#  'em': 952,
#  'hospital': 953,
#  'card': 954,
#  'yo': 955,
#  'drunk': 956,
#  'sign': 957,
#  'profile': 958,
#  'finals': 959,
#  'taken': 960,
#  'paper': 961,
#  'although': 962,
#  'twilight': 963,
#  'books': 964,
#  'garden': 965,
#  'yup': 966,
#  'case': 967,
#  'scary': 968,
#  'club': 969,
#  'bloody': 970,
#  'woo': 971,
#  'clothes': 972,
#  'each': 973,
#  'lakers': 974,
#  'proud': 975,
#  'film': 976,
#  'front': 977,
#  'episode': 978,
#  'question': 979,
#  'ahead': 980,
#  'killing': 981,
#  'cup': 982,
#  'lately': 983,
#  'cd': 984,
#  "it'll": 985,
#  'fantastic': 986,
#  'except': 987,
#  'j': 988,
#  'ouch': 989,
#  'safe': 990,
#  'cos': 991,
#  'alot': 992,
#  'pass': 993,
#  'needed': 994,
#  'lame': 995,
#  'living': 996,
#  'played': 997,
#  'worked': 998,
#  'wednesday': 999,
#  'giving': 1000,
#  ...}

# %% [markdown]
# **Creación de secuencias y padding**
#
# Estas líneas de código se utilizan para asegurar que todas las secuencias de texto tengan la misma longitud. Esto es necesario porque muchos modelos de redes neuronales requieren que la entrada tenga un tamaño fijo.
#
# Primero, se calcula el tamaño del vocabulario a partir del objeto tokenizer creado anteriormente. Esto se hace sumando 1 al número de palabras únicas en el vocabulario, ya que el índice 0 se reserva para un token especial que se utiliza para rellenar las secuencias más cortas.
#
# Luego, se establece la longitud máxima de las secuencias en 120. Esto significa que todas las secuencias se cortarán o rellenarán hasta tener una longitud de 120 tokens.
#
# Finalmente, se utiliza la función pad_sequences de Keras para rellenar o cortar las secuencias de entrenamiento, validación y prueba hasta tener una longitud de 120. La opción padding='post' indica que el relleno se debe añadir al final de la secuencia. Si se elige padding='pre', el relleno se añadirá al principio de la secuencia.

# %%
vocab_size = len(tokenizer.word_index) + 1
maxlen = 120

X_train_pad = pad_sequences(X_train_seq, padding='post', maxlen=maxlen)
X_valid_pad = pad_sequences(X_valid_seq, padding='post', maxlen=maxlen)
X_test_pad = pad_sequences(X_test_seq, padding='post', maxlen=maxlen)

X_train_pad
# Out:
# array([[ 15626,    116,     70, ...,      0,      0,      0],
#        [  8297,      5,    977, ...,      0,      0,      0],
#        [ 39706,      1,     46, ...,      0,      0,      0],
#        ...,
#        [139111,   1139,  16238, ...,      0,      0,      0],
#        [139115,    507,   1571, ...,      0,      0,      0],
#        [     1,     64,    558, ...,      0,      0,      0]], dtype=int32)

# %% [markdown]
# ## Red neuronal RNN básica con pooling: comparación embeddings 100/200/300

# %% [markdown]
# **Con embeddings de 100 dimensiones**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 100                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.5373 - loss: 0.6860 - val_accuracy: 0.6714 - val_loss: 0.6315
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7048 - loss: 0.6043 - val_accuracy: 0.6423 - val_loss: 0.6468
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7416 - loss: 0.5658 - val_accuracy: 0.6457 - val_loss: 0.6574
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.7651 - loss: 0.5305 - val_accuracy: 0.6812 - val_loss: 0.6293
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.7864 - loss: 0.4976 - val_accuracy: 0.7109 - val_loss: 0.5985

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7062 - loss: 0.6029
#
# Precisión en test: 0.7102

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.68      0.80      0.74     10000
#   1:positive       0.76      0.62      0.68     10000
#
#     accuracy                           0.71     20000
#    macro avg       0.72      0.71      0.71     20000
# weighted avg       0.72      0.71      0.71     20000

# %% [markdown]
# **Con embeddings de 200 dimensiones**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 200                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.5765 - loss: 0.6764 - val_accuracy: 0.7139 - val_loss: 0.5982
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.7670 - loss: 0.5411 - val_accuracy: 0.6569 - val_loss: 0.6218
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8027 - loss: 0.4872 - val_accuracy: 0.7181 - val_loss: 0.5832
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.8569 - loss: 0.4046 - val_accuracy: 0.7168 - val_loss: 0.5987
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.8804 - loss: 0.3395 - val_accuracy: 0.7156 - val_loss: 0.5801

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7086 - loss: 0.5876
#
# Precisión en test: 0.7147

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.69      0.77      0.73     10000
#   1:positive       0.74      0.66      0.70     10000
#
#     accuracy                           0.71     20000
#    macro avg       0.72      0.71      0.71     20000
# weighted avg       0.72      0.71      0.71     20000

# %% [markdown]
# **Con embeddings de 300 dimensiones**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.5747 - loss: 0.6801 - val_accuracy: 0.5111 - val_loss: 0.7800
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.7053 - loss: 0.5988 - val_accuracy: 0.7333 - val_loss: 0.5646
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.8165 - loss: 0.4734 - val_accuracy: 0.7190 - val_loss: 0.5844
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8554 - loss: 0.4194 - val_accuracy: 0.7174 - val_loss: 0.5951
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8846 - loss: 0.3504 - val_accuracy: 0.7225 - val_loss: 0.6211

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7171 - loss: 0.6335
#
# Precisión en test: 0.7211

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.70      0.78      0.74     10000
#   1:positive       0.75      0.67      0.71     10000
#
#     accuracy                           0.72     20000
#    macro avg       0.72      0.72      0.72     20000
# weighted avg       0.72      0.72      0.72     20000

# %% [markdown]
# **Nos quedamos con los embeddings de 300 dimensiones para el resto de los modelos, ya que son los que mejores resultados nos han dado hasta ahora (aunque la diferencia es mínima, de solo 0.01 en el weighted avg del f1-score).**

# %% [markdown]
# ## Red neuronal RNN básica con pooling y embeddings de 300 dimensiones: comparación 64, 128 y 256 neuronas

# %% [markdown]
# **Con 128 neuronas**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_6 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_6      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.5721 - loss: 0.6768 - val_accuracy: 0.5208 - val_loss: 0.6926
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.6893 - loss: 0.6194 - val_accuracy: 0.7202 - val_loss: 0.5906
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.8015 - loss: 0.5106 - val_accuracy: 0.7222 - val_loss: 0.5684
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8331 - loss: 0.4391 - val_accuracy: 0.7176 - val_loss: 0.5953
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8676 - loss: 0.3828 - val_accuracy: 0.7211 - val_loss: 0.5923

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7201 - loss: 0.5984
#
# Precisión en test: 0.7241

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.73      0.72      0.72     10000
#   1:positive       0.72      0.73      0.73     10000
#
#     accuracy                           0.72     20000
#    macro avg       0.72      0.72      0.72     20000
# weighted avg       0.72      0.72      0.72     20000

# %% [markdown]
# **Con 64 neuronas**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(64, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_7 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_7      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - accuracy: 0.6027 - loss: 0.6619 - val_accuracy: 0.6693 - val_loss: 0.6279
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - accuracy: 0.7145 - loss: 0.5764 - val_accuracy: 0.6623 - val_loss: 0.6395
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7712 - loss: 0.5340 - val_accuracy: 0.6698 - val_loss: 0.6518
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.7994 - loss: 0.4935 - val_accuracy: 0.5293 - val_loss: 0.6858

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5341 - loss: 0.6855
#
# Precisión en test: 0.5306

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.82      0.08      0.14     10000
#   1:positive       0.52      0.98      0.68     10000
#
#     accuracy                           0.53     20000
#    macro avg       0.67      0.53      0.41     20000
# weighted avg       0.67      0.53      0.41     20000

# %% [markdown]
# **Con 256 neuronas**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                         # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(256, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_8 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_8      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 52ms/step - accuracy: 0.5555 - loss: 0.6841 - val_accuracy: 0.6442 - val_loss: 0.6375
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.6556 - loss: 0.6419 - val_accuracy: 0.6981 - val_loss: 0.6265
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.7713 - loss: 0.5423 - val_accuracy: 0.7556 - val_loss: 0.5094
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.8490 - loss: 0.3528 - val_accuracy: 0.7507 - val_loss: 0.5892
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.8509 - loss: 0.4149 - val_accuracy: 0.6752 - val_loss: 0.6485

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6701 - loss: 0.6499
#
# Precisión en test: 0.6755

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.68      0.67      0.67     10000
#   1:positive       0.67      0.69      0.68     10000
#
#     accuracy                           0.68     20000
#    macro avg       0.68      0.68      0.68     20000
# weighted avg       0.68      0.68      0.68     20000

# %% [markdown]
# **Nos quedamos con las 128 neuronas y los embeddings de 100 dimensiones para el resto de los modelos, ya que son los que mejores resultados nos han dado hasta ahora.**

# %% [markdown]
# ## Red neuronal RNN básica con pooling, 128 neuronas y embeddings de 300 dimensiones: comparación de 5, 10, 20 y 50 epochs

# %% [markdown]
# **Con 5 epochs (patience 3)**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_9      │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=5,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.5970 - loss: 0.6682 - val_accuracy: 0.7336 - val_loss: 0.5784
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.7644 - loss: 0.5408 - val_accuracy: 0.6991 - val_loss: 0.6155
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.8136 - loss: 0.5147 - val_accuracy: 0.7181 - val_loss: 0.5872
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - accuracy: 0.8595 - loss: 0.4207 - val_accuracy: 0.7207 - val_loss: 0.5874

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7213 - loss: 0.5914
#
# Precisión en test: 0.7229

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.71      0.76      0.73     10000
#   1:positive       0.74      0.69      0.71     10000
#
#     accuracy                           0.72     20000
#    macro avg       0.72      0.72      0.72     20000
# weighted avg       0.72      0.72      0.72     20000

# %% [markdown]
# **Con 10 epochs (patience 3)**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_10 (SimpleRNN)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_10     │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=10,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.5869 - loss: 0.6722 - val_accuracy: 0.6606 - val_loss: 0.6353
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - accuracy: 0.7167 - loss: 0.5881 - val_accuracy: 0.5329 - val_loss: 0.6797
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.6507 - loss: 0.6523 - val_accuracy: 0.7329 - val_loss: 0.6028
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8066 - loss: 0.5107 - val_accuracy: 0.7291 - val_loss: 0.5740
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.8518 - loss: 0.4182 - val_accuracy: 0.7421 - val_loss: 0.6411
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.8728 - loss: 0.3291 - val_accuracy: 0.7451 - val_loss: 0.5533
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8906 - loss: 0.3055 - val_accuracy: 0.7426 - val_loss: 0.5798
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9069 - loss: 0.2629 - val_accuracy: 0.7521 - val_loss: 0.6019
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9150 - loss: 0.2467 - val_accuracy: 0.7431 - val_loss: 0.6400

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7377 - loss: 0.6578
#
# Precisión en test: 0.7436

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.75      0.73      0.74     10000
#   1:positive       0.74      0.75      0.75     10000
#
#     accuracy                           0.74     20000
#    macro avg       0.74      0.74      0.74     20000
# weighted avg       0.74      0.74      0.74     20000

# %% [markdown]
# **Con 20 epochs (patience 5)**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_11 (SimpleRNN)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_11     │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=5)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=20,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.5680 - loss: 0.6872 - val_accuracy: 0.6854 - val_loss: 0.6463
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - accuracy: 0.7301 - loss: 0.6023 - val_accuracy: 0.7241 - val_loss: 0.5764
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8086 - loss: 0.4912 - val_accuracy: 0.7203 - val_loss: 0.5815
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.8553 - loss: 0.4120 - val_accuracy: 0.7107 - val_loss: 0.6174
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8801 - loss: 0.3585 - val_accuracy: 0.7176 - val_loss: 0.6326
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8963 - loss: 0.3103 - val_accuracy: 0.7181 - val_loss: 0.6805
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.9081 - loss: 0.2769 - val_accuracy: 0.7221 - val_loss: 0.6153

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7218 - loss: 0.6228
#
# Precisión en test: 0.7271

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.72      0.75      0.73     10000
#   1:positive       0.74      0.70      0.72     10000
#
#     accuracy                           0.73     20000
#    macro avg       0.73      0.73      0.73     20000
# weighted avg       0.73      0.73      0.73     20000

# %% [markdown]
# **Con 50 epochs (patience 10)**
#
# Esta alternativa recoge todos los estados ocultos generados para cada token y aplica una operación de pooling para obtener una representación global del texto. Aquí se muestra el ejemplo usando pooling de media, aunque se puede usar también el pooling máximo.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, GlobalAveragePooling1D, Dense


# Modelo simplificado con pooling para clasificación de sentimientos
# Parámetros de ejemplo
vocab_size = len(tokenizer.word_index) + 1   # Tamaño del vocabulario
embedding_dim = 300                          # Dimensión de los embeddings

model_pool = Sequential([
    # Capa de Embedding: Representa cada palabra en un espacio vectorial.
    Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=maxlen,
              trainable=True),

    # Capa RNN: Procesa la secuencia completa y devuelve todos los estados ocultos.
    # Esto permite aplicar pooling a lo largo de la secuencia.
    SimpleRNN(128, return_sequences=True),

    # Pooling: Calcula la media de los estados ocultos para obtener una representación global.
    GlobalAveragePooling1D(),

    # Capa de Clasificación: Toma la representación agregada y asigna probabilidades a cada clase.
    Dense(1, activation='sigmoid')
])

model_pool.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

model_pool.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_12 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_12 (SimpleRNN)       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_12     │ ?                      │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La función fit de Keras se utiliza para entrenar un modelo a partir de datos de entrenamiento.

# %%
# Entrenamiento con early stopping
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10)

history = model_pool.fit(X_train_pad, y_train,
                    epochs=50,
                    batch_size=512, # se recomiendo batches de menor tamaño para mejor rendimiento (pero entrenamiento toma más tiempo)
                    validation_data=(X_valid_pad, y_valid),
                    callbacks=[early_stop])
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.6049 - loss: 0.6728 - val_accuracy: 0.5666 - val_loss: 0.6711
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.7418 - loss: 0.5640 - val_accuracy: 0.7335 - val_loss: 0.5648
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.8096 - loss: 0.4814 - val_accuracy: 0.6569 - val_loss: 0.6737
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8425 - loss: 0.4126 - val_accuracy: 0.7401 - val_loss: 0.5450
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8690 - loss: 0.3760 - val_accuracy: 0.7231 - val_loss: 0.5839
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8893 - loss: 0.3245 - val_accuracy: 0.7333 - val_loss: 0.5989
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.8834 - loss: 0.3314 - val_accuracy: 0.7484 - val_loss: 0.5919
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9035 - loss: 0.2601 - val_accuracy: 0.7414 - val_loss: 0.5997
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.9130 - loss: 0.2483 - val_accuracy: 0.7240 - val_loss: 0.6439
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.9207 - loss: 0.2407 - val_accuracy: 0.7265 - val_loss: 0.6339
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9290 - loss: 0.2131 - val_accuracy: 0.7390 - val_loss: 0.7853
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9387 - loss: 0.1684 - val_accuracy: 0.7390 - val_loss: 0.9189
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.9456 - loss: 0.1482 - val_accuracy: 0.7379 - val_loss: 0.8353
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.9503 - loss: 0.1376 - val_accuracy: 0.7414 - val_loss: 0.7202

# %%
# Evaluación del modelo
test_loss, test_acc = model_pool.evaluate(X_test_pad, y_test)
print(f"\nPrecisión en test: {test_acc:.4f}")
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7436 - loss: 0.7284
#
# Precisión en test: 0.7465

# %%
# Visualización del entrenamiento
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Validación')
plt.title('Precisión por época')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Entrenamiento')
plt.plot(history.history['val_loss'], label='Validación')
plt.title('Pérdida por época')
plt.legend()
plt.show()

# %%
# Predicción binaria: salida de sigmoid
y_pred = (model_pool.predict(X_test_pad) > 0.5).astype("int32").flatten()

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
plt.imshow(cm, cmap='Blues')
plt.colorbar()
plt.xticks(ticks=[0, 1], labels=['0', '1'])
plt.yticks(ticks=[0, 1], labels=['0', '1'])
plt.xlabel('Predicciones')
plt.ylabel('Reales')
plt.title('Matriz de Confusión - RNN Simple con pooling')
plt.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
# Análisis de errores frecuentes
print(classification_report(y_test, y_pred, target_names=['0:negative', '1:positive']))
# Out:
#               precision    recall  f1-score   support
#
#   0:negative       0.77      0.71      0.74     10000
#   1:positive       0.73      0.78      0.76     10000
#
#     accuracy                           0.75     20000
#    macro avg       0.75      0.75      0.75     20000
# weighted avg       0.75      0.75      0.75     20000

# %% [markdown]
# **Nos quedamos con las 128 neuronas, los embeddings de 300 dimensiones y los 50 epochs con patience 10 para el resto de los modelos, ya que son los que mejores resultados nos han dado hasta ahora. De hecho, conseguimos una f1-score de 0.75 tanto para accuracy como para macro avg y weighted avg. Este es el mejor resultado que hemos obtenido de todas las combinaciones que hemos probado.**

# %% [markdown]
# Para probar distintas combinaciones de parámetros, he seguido una metodología sistemática y coherente comprobando primero las variaciones de uno solo parámetro para así quedarme con la opción que mejores resultados ofrece. Definido así el primer parámetro, podemos pasar al siguiente y probar también todas sus opciones manteniendo estable el primer parámetro seleccionado para todas ellas, y así sucesivamente, hasta que todos hayan quedado definidos.
#
# Durante el proceso de entrenamiento del modelo con una red neuronal básica con pooling, he evaluado distintas configuraciones para encontrar la combinación óptima teniendo en cuenta los siguientes factores: dimensión de los embeddings, número de neuronas en la capa oculta y número de épocas (con la patience correspondiente). Después del experimento nos quedamos con las 128 neuronas, los embeddings de 300 dimensiones y los 50 epochs con patience 10, ya que son los que mejores resultados nos han dado hasta ahora. De hecho, conseguimos una f1-score de 0.75 tanto para accuracy como para macro avg y weighted avg. Este es el mejor resultado que hemos obtenido de todas las combinaciones que hemos probado.
#
# **Dimensión de los embeddings**: He probado con vectores de embeddings de 100, 200 y 300 dimensiones. El modelo con embeddings de 300 dimensiones es el que ha obtenido el mejor rendimiento general. Esto puede explicarse porque los embeddings de mayor dimensión permiten una representación semántica más rica de las palabras, capturando matices más complejos del lenguaje. Aunque los embeddings de menor dimensión son más eficientes computacionalmente, en este caso la mejora en la precisión justifica el coste computacional mayor en el que incurrimos.
#
# **Número de neuronas en la capa oculta**: Una vez fijado el tamaño óptimo de los embeddings (300 dimensiones), he probado de adaptar la capacidad del modelo variando el número de neuronas en la capa densa (64, 128 y 256). El mejor rendimiento lo he conseguido con 128 neuronas, que, al ser la opción intermedia, equilibra la capacidad de aprendizaje y el riesgo de sobreajuste. Con 64 neuronas, el modelo probablemente no disponía de suficiente capacidad para aprender patrones complejos; mientras que con 256 neuronas, no hubo una mejora significativa debido al sobreajuste.
#
# **Número de épocas de entrenamiento**: Por último, he experimentado con distintas duraciones del entrenamiento (5, 10, 20 y 50 épocas). Cabe comentar que la variación en la cantidad de epochs no ha modificado prácticamente nada los resultados. De todas formas, debemos tener en cuenta que siempre hemos adaptado la patience proporcionalmente a la cantidad de epochs seleccionada, pudiendo ser este un aspecto que ha incidido en los resultados. En conclusión, esto justificaría que no hayamos observado diferencias significativas en el rendimiento final. De hecho, esto permite que el modelo deje de entrenar una vez alcanzada la convergencia, independientemente del máximo de épocas establecido. Este comportamiento indica que el modelo converge rápidamente y que extender las épocas más allá de un cierto punto no aporta más beneficios.

# %% [markdown]
# #MODELO DEFINITIVO PARA RNNs

# %% [markdown]
# No es necesario volñver a cargarlo, ya que es el último que hemos ejecutado. Por ello, cuando recurramos a variables como y_pred, seran las aportadas por las predicciones de este modelo, que ha sido el seleccionado por mostrar un rendimiento superior al resto.

# %%
df_test
# Out:
#                                                      text  polarity split
# 8820    It's saturday, cold and rainy, where has summe...         0  test
# 83415   Today is a *very* tired Monday.  Weekend was n...         0  test
# 113734       @daverosstomlin watch the profanity finchy.          4  test
# 88517                              @tommcfly no, I'm not          0  test
# 108885  @QueenBea33 why were u mad?? and ooh i wanna s...         4  test
# ...                                                   ...       ...   ...
# 2763    The 1st class flight attendant is so hawt yall...         0  test
# 90202                        is incredibly sad right now          0  test
# 140825  Is Twitter working again??? Is it safe to come...         4  test
# 95102   @PioneerHall argg I feel so bad that I was tol...         0  test
# 17316                                He Still Has My (L)          0  test
#
# [20000 rows x 3 columns]

# %%
df_test["polarity"] = df_test["polarity"].map({0: 0, 4: 1})

# %%
df_test
# Out:
#                                                      text  polarity split
# 8820    It's saturday, cold and rainy, where has summe...         0  test
# 83415   Today is a *very* tired Monday.  Weekend was n...         0  test
# 113734       @daverosstomlin watch the profanity finchy.          1  test
# 88517                              @tommcfly no, I'm not          0  test
# 108885  @QueenBea33 why were u mad?? and ooh i wanna s...         1  test
# ...                                                   ...       ...   ...
# 2763    The 1st class flight attendant is so hawt yall...         0  test
# 90202                        is incredibly sad right now          0  test
# 140825  Is Twitter working again??? Is it safe to come...         1  test
# 95102   @PioneerHall argg I feel so bad that I was tol...         0  test
# 17316                                He Still Has My (L)          0  test
#
# [20000 rows x 3 columns]

# %%
df_test["predicted_label"] = y_pred

# %%
df_test
# Out:
#                                                      text  polarity split  \
# 8820    It's saturday, cold and rainy, where has summe...         0  test
# 83415   Today is a *very* tired Monday.  Weekend was n...         0  test
# 113734       @daverosstomlin watch the profanity finchy.          1  test
# 88517                              @tommcfly no, I'm not          0  test
# 108885  @QueenBea33 why were u mad?? and ooh i wanna s...         1  test
# ...                                                   ...       ...   ...
# 2763    The 1st class flight attendant is so hawt yall...         0  test
# 90202                        is incredibly sad right now          0  test
# 140825  Is Twitter working again??? Is it safe to come...         1  test
# 95102   @PioneerHall argg I feel so bad that I was tol...         0  test
# 17316                                He Still Has My (L)          0  test
#
#         predicted_label
# 8820                  1
# 83415                 1
# 113734                1
# 88517                 0
# 108885                1
# ...                 ...
# 2763                  1
# 90202                 1
# 140825                1
# 95102                 1
# 17316                 0
#
# [20000 rows x 4 columns]

# %%
df_test.loc[8820, "text"]
# Out:
# "It's saturday, cold and rainy, where has summer gone? "

# %%
df_test.loc[83415, "text"]
# Out:
# 'Today is a *very* tired Monday.  Weekend was not good for catching up on sleep as I hoped it would be.  Makes me write in passive voice. '

# %%
df_test.loc[2763, "text"]
# Out:
# 'The 1st class flight attendant is so hawt yall....but o so GAY '

# %%
df_test.loc[90202, "text"]
# Out:
# 'is incredibly sad right now '

# %%
df_test.loc[95102, "text"]
# Out:
# "@PioneerHall argg I feel so bad that I was told the wrong time, then told everyone else the wrong time!  my mind hasn't been with me"

# %% [markdown]
# #LIME

# %%
# !pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.5.10)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=be92f20b883bc1a6d30a78eb967a084ddf6dd9c4deac9f467da22559facb0f15
#   Stored in directory: /root/.cache/pip/wheels/85/fa/a3/9c2d44c9f3cd77cf4e533b58900b2bf4487f2a17e8ec212a3d
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
from lime.lime_text import LimeTextExplainer
# Función de predicción para LIME
def predict_lime(texts):
    sequences = tokenizer.texts_to_sequences(texts)
    padded = pad_sequences(sequences, maxlen=maxlen)
    return model_pool.predict(padded)

# Crear explicador
explainer = LimeTextExplainer(class_names=['negative', 'positive'])

# %%
# Explicar una predicción
idx = 88517  # Índice del ejemplo a explicar
exp = explainer.explain_instance(X_test[idx], predict_lime, num_features=10, top_labels=2)

# Mostrar explicación
exp.show_in_notebook(text=X_test[idx])
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s
